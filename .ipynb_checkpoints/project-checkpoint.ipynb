# %% [markdown]
# # FIT5196 Assessment 2
#
# #### Student Name: Ibrahim Al-Hindi
# #### Date Created: 20/09/2021
# #### Date Last Edited: 03/10/2021
#
# Environment Details:
# - Python: 3.8.10
# - Anaconda: 4.10.3
#
# Libraries Used:
# - pandas
# - numpy
# - matplotlib
# - nltk
# - re
# - datetime
# - networkx
# - sklearn
# - ast
#
# ## 1. Introduction
#
# This assignment is concerned with exhibiting the critical importance of data wrangling and data cleansing for a given dataset. Three files created from the same origin will be used in this report. The files contain data for a food delivery service and contain information such as restaurant, customer, date, price, and others. The first section of the report will examine the first file which contains a multitude of errors of various types, the task is to identify and fix all the errors present in the file. The second section of the report concerns a file that contains missing data and the task is to impute those missing values. The third section is analysing a file with outliers in one of its columns, where the task is to identify and remove the rows with the outliers. It is important to note that all three files stem from the same source file, as such some of the files will be used to tackle issues in other files in some of the sections contained in this report.

# %% [markdown]
# ## 2. Import Libraries and Load Data Files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re
import datetime as dt
import networkx as nx
from sklearn.linear_model import LinearRegression
from ast import literal_eval
# %matplotlib inline

# %%
dirty = pd.read_csv("./data/dirty.csv")
missing = pd.read_csv("./data/missing.csv")
outliers = pd.read_csv("./data/outlier.csv")

# %% [markdown]
# As our analysis will require us to use the three files interchangeably, we will verify that all three files contain the same unique restaurants according to the `restaurant_id` column

# %%
print("dirty:   ", sorted(list(dirty["restaurant_id"].unique())))
print("missing: ", sorted(list(missing["restaurant_id"].unique())))
print("outliers:", sorted(list(outliers["restaurant_id"].unique())))
# Out:
# dirty:    ['REST0936', 'REST1450', 'REST1781', 'REST1801', 'REST1858']
# missing:  ['REST0936', 'REST1450', 'REST1781', 'REST1801', 'REST1858']
# outliers: ['REST0936', 'REST1450', 'REST1781', 'REST1801', 'REST1858']

# %% [markdown]
# The three files contain the same restaurants

# %% [markdown]
# ## 3. Dirty Data
#
# The first part of the report will examine the `dirty` file which contains errors and proceed to fix those errors.
#
# ### 3.1 Data Exploration
#
# A preliminary exploration will be performed

# %% [markdown]
# Let's take a look at the first and last five rows of the data

# %%
dirty
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 0    ORD057034      REST0936   CUST13295   COUR1776    -37.822927
# 1    ORD079938      REST1450   CUST00146   COUR0059    -37.802062
# 2    ORD211273      REST1450   CUST08503   COUR0136    -37.816395
# 3    ORD009241      REST0936   CUST11478   COUR0989    -37.822199
# 4    ORD340665      REST1801   CUST05997   COUR0969    -37.806474
# ..         ...           ...         ...        ...           ...
# 495  ORD207789      REST1801   CUST00873   COUR1878    -37.813804
# 496  ORD308208      REST1858   CUST07405   COUR3984    -37.824076
# 497  ORD133436      REST1801   CUST07334   COUR3943    -37.819943
# 498  ORD049884      REST1801   CUST10882   COUR1990    -37.806158
# 499  ORD283053      REST0936   CUST07472   COUR3468    -37.803969
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 0      144.980852  2020-06-20  17:24:23             0           1
# 1      144.965365  2020-12-18  13:15:09             1           0
# 2      144.938170  2020-02-17  07:19:07             0           0
# 3      144.947623  2020-03-26  06:47:28             0           0
# 4      144.966435  2020-05-02  08:34:17             0           1
# ..            ...         ...       ...           ...         ...
# 495    144.953112  2020-06-27  19:19:07             1           1
# 496    144.968529  2020-08-07  10:05:16             0           0
# 497    144.968655  2020-12-12  14:50:06             0           1
# 498    144.951672  2020-07-26  13:19:07             1           1
# 499    145.010975  2020-04-14  05:40:13             0           0
#
#     carrier_vehicle                                      shopping_cart  \
# 0         Motorbike  [('cheesecake', 2), ('tender coconut ice cream...
# 1         Motorbike                     [('rasgulla', 1), ('poha', 2)]
# 2         Motorbike  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...
# 3               Car             [('mocha chingri', 3), ('paratha', 3)]
# 4         Motorbike  [('tandoori chicken', 2), ('hyderabadi biryani...
# ..              ...                                                ...
# 495       Motorbike   [('hyderabadi biryani', 1), ('panner tikka', 2)]
# 496            Bike   [('appam', 2), ('mackerel fry', 3), ('fish', 2)]
# 497             Car  [('hyderabadi biryani', 3), ('chicken boneless...
# 498             Car  [('hyderabadi biryani', 1), ('chicken boneless...
# 499       Motorbike           [('banana chips', 3), ('cheesecake', 2)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 0                  0      122.080                           5413
# 1                 45       21.246                           2687
# 2                  0       81.530                           2052
# 3                 10       77.841                           2594
# 4                  0       60.720                           1235
# ..               ...          ...                            ...
# 495               20       15.968                           2071
# 496               45       60.836                           1718
# 497               10       41.058                           2612
# 498                0       97.300                           1416
# 499                0       83.040                           7842
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 0                     11               9.58            4.7296
# 1                      5               7.71            4.6335
# 2                     20               7.71            3.2905
# 3                      6               7.66            3.0872
# 4                      2               9.72            3.7126
# ..                   ...                ...               ...
# 495                    4               9.72            5.4043
# 496                    9               5.65            4.2505
# 497                    6               9.72            3.7264
# 498                    3               9.72            5.3832
# 499                   16               9.58            4.4958
#
# [500 rows x 18 columns]

# %%
dirty.shape
# Out:
# (500, 18)

# %% [markdown]
# The data consists of 500 observations of 18 columns

# %% [markdown]
# Let's examine the types of variables in our data

# %%
dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       500 non-null    object
#  1   restaurant_id                  500 non-null    object
#  2   customer_id                    500 non-null    object
#  3   carrier_id                     500 non-null    object
#  4   customer_lat                   500 non-null    float64
#  5   customer_lon                   500 non-null    float64
#  6   date                           500 non-null    object
#  7   time                           500 non-null    object
#  8   is_peak_time                   500 non-null    int64
#  9   is_weekend                     500 non-null    int64
#  10  carrier_vehicle                500 non-null    object
#  11  shopping_cart                  500 non-null    object
#  12  coupon_discount                500 non-null    int64
#  13  order_price                    500 non-null    float64
#  14  shortest_distance_to_customer  500 non-null    int64
#  15  travel_time_minutes            500 non-null    int64
#  16  restaurant_rating              500 non-null    float64
#  17  delivery_charges               500 non-null    float64
# dtypes: float64(5), int64(5), object(8)
# memory usage: 70.4+ KB

# %% [markdown]
# We have 10 numerical and 8 categorical variables

# %% [markdown]
# Let's examine the summary statistics of the numerical variables

# %%
dirty.describe()
# Out:
#        customer_lat  customer_lon  is_peak_time  is_weekend  coupon_discount  \
# count    500.000000    500.000000    500.000000  500.000000       500.000000
# mean     -35.619351    142.774161      0.150000    0.288000        15.430000
# std       19.920744     19.921726      0.357429    0.453285        17.832585
# min      -37.829620    -37.815714      0.000000    0.000000         0.000000
# 25%      -37.818879    144.951738      0.000000    0.000000         0.000000
# 50%      -37.812585    144.964346      0.000000    0.000000        10.000000
# 75%      -37.806252    144.981855      0.000000    1.000000        40.000000
# max      145.004298    145.016298      1.000000    1.000000        45.000000
#
#        order_price  shortest_distance_to_customer  travel_time_minutes  \
# count   500.000000                     500.000000            500.00000
# mean     75.951338                    2953.828000              9.22800
# std      37.506635                    1634.293413              7.00272
# min      10.439000                      14.000000              0.00000
# 25%      49.695750                    1805.750000              4.75000
# 50%      69.352000                    2661.500000              7.00000
# 75%      99.164250                    3823.250000             12.00000
# max     192.310000                   10792.000000             42.00000
#
#        restaurant_rating  delivery_charges
# count         500.000000        500.000000
# mean            7.590480          4.137222
# std             1.264089          0.975299
# min             5.650000          2.483400
# 25%             6.620000          3.390325
# 50%             7.660000          3.984700
# 75%             8.270000          4.747425
# max             9.720000          8.014900

# %% [markdown]
# Already we can see some errors such as the maximum of **145.004298** under `customer_lat` and, conversely, the minimum of **-37.814714** under `customer_lon`. Let's examine the summary statistics of the categorical variables

# %%
dirty.describe(include = "O")
# Out:
#          order_id restaurant_id customer_id carrier_id        date      time  \
# count         500           500         500        500         500       500
# unique        500             5         491        478         277       280
# top     ORD057034      REST0936   CUST02764   COUR2625  2020-09-02  06:11:52
# freq            1           118           2          2           6         5
#
#        carrier_vehicle                     shopping_cart
# count              500                               500
# unique               6                               488
# top          Motorbike  [('roast beef', 3), ('fish', 2)]
# freq               187                                 2

# %% [markdown]
# Further exploration will be performed to discover and solve errors further along the report.
#
# The errors will now be located and corrected. The columns to be examined and corrected if necessary (in no specific order) are:
#
# - customer_lat
# - customer_lon
# - date
# - is_peak_time
# - is_weekend
# - carrier_vehicle
# - coupon_discount
# - order_price
# - shortest_distance_to_customer
# - travel_time_minutes
# - restaurant_rating
#
# ### 3.2 restaurant_rating
#
# Referencing the table above examining the categorical variables, we can see that we have five unique `restaurant_id`. We should therefore have only five unique restaurant ratings. We actually have the following number of unique restaurant ratings:

# %%
len(dirty["restaurant_rating"].unique())
# Out:
# 10

# %% [markdown]
# We can see the ratings for each restaurant by generating the unique `restaurant_rating` after grouping by `restaurant_id`

# %%
original_ratings = dirty.groupby(dirty["restaurant_id"])["restaurant_rating"].unique()
original_ratings
# Out:
# restaurant_id
# REST0936    [9.58, 7.66]
# REST1450    [7.71, 6.17]
# REST1781    [8.27, 6.62]
# REST1801    [9.72, 7.78]
# REST1858    [7.06, 5.65]
# Name: restaurant_rating, dtype: object

# %% [markdown]
# As we have 2 restaurant ratings per `restaurant_id` instead of one, the true restaurant ratings will be generated and inserted into the data. To calculate the true restaurant rating for each restaurant, `SentimentIntensityAnalyzer` from `nltk.sentiment.vader` will be implemented on the reviews of each restaurant to calculate the average polarity (avg_polarity) per restaurant, then the rating will be calculated using the following formula:
#
# **10 * (avg_polarity + 0.9623) / (1.9533)**
#
# First, the file containing information regarding each restaurant including their reviews will be read in

# %%
rest_data = pd.read_csv("./supplementary_data/restaurant_data_student.csv")
rest_data.head()
# Out:
#   restaurant_id  restaurant_name  \
# 0      REST0000            jalsa
# 1      REST0001   spice elephant
# 2      REST0002  san churro cafe
# 3      REST0003  timepass dinner
# 4      REST0004           onesta
#
#                                           menu_items  \
# 0  ['biryani', 'butter chicken', 'dal makhani', '...
# 1  ['chicken biryani', 'chocolate nirvana', 'dum ...
# 2  ['cannelloni', 'churros', 'hot chocolate', 'mi...
# 3  ['jeera rice', 'kadhai paneer', 'onion rings',...
# 4  ['apple pie', 'bacon pizza', 'banana smoothie'...
#
#                                         reviews_list        lat         lon  \
# 0  ['* great place for families* mughal theme foo... -37.821295  144.987506
# 1  ['a decent place for a family lunch or dinner.... -37.805811  144.938170
# 2  ["rated went there for a quick bite with frien... -37.815720  144.950524
# 3  ["came over here with family unexpectedly on v... -37.812461  144.953430
# 4  ['rated best place for pizzas. we had bacon wr... -37.821704  145.009534
#
#    rest_nodes
# 0  1445473970
# 1  3555788741
# 2   579489323
# 3  5002595078
# 4   331417007

# %% [markdown]
# We will filter `rest_data` to only contain the `restaurant_id`s present in the dirty data

# %%
rest_data_match = rest_data[rest_data["restaurant_id"].isin(dirty["restaurant_id"])]
rest_data_match
# Out:
#      restaurant_id restaurant_name  \
# 936       REST0936        eatwater
# 1450      REST1450     uday sweets
# 1781      REST1781          django
# 1801      REST1801   plantain leaf
# 1858      REST1858      achayyan's
#
#                                              menu_items  \
# 936   ['banana chips', 'begun pora', 'cheesecake', '...
# 1450  ['jalebi', 'kachori', 'poha', 'puri sabzi', 'r...
# 1781  ['beef burger', 'burgers', 'chicken burger', '...
# 1801  ['chicken boneless biryani', 'chicken guntur',...
# 1858  ['appam', 'beef fry', 'crab toast', 'fish', 'k...
#
#                                            reviews_list        lat  \
# 936   ['ambience: 4/5. food: 4/5. have been looking ... -37.806573
# 1450  ['for those looking for good poori-bhaji optio... -37.818838
# 1781  ['100', 'a quaint little place just off the hu... -37.814318
# 1801  ['mind blowing quality quantity and taste of t... -37.799938
# 1858  ["achayyans was our favourite lunch place for ... -37.821556
#
#              lon  rest_nodes
# 936   144.932239  3106292227
# 1450  144.954890  6167191696
# 1781  144.965565  1327098193
# 1801  144.960628   871096404
# 1858  144.983925  4380043465

# %% [markdown]
# All the columns except for `restaurant_id` and `reviews_list` will be dropped

# %%
rest_data_rating = rest_data_match.drop(columns = ["restaurant_name", "menu_items", "lat", "lon", "rest_nodes"])
rest_data_rating
# Out:
#      restaurant_id                                       reviews_list
# 936       REST0936  ['ambience: 4/5. food: 4/5. have been looking ...
# 1450      REST1450  ['for those looking for good poori-bhaji optio...
# 1781      REST1781  ['100', 'a quaint little place just off the hu...
# 1801      REST1801  ['mind blowing quality quantity and taste of t...
# 1858      REST1858  ["achayyans was our favourite lunch place for ...

# %% [markdown]
# We now have the five restaurants we need with their reviews.

# %% [markdown]
# We will now utilise the sentiment analyzer. First we initialize a sentiment analyzer object

# %%
# initialize
sid = SentimentIntensityAnalyzer()

# %% [markdown]
# The function `rat_gen` will be created whereby the list of reviews for a restaurant will be passed in as an argument and will return a rating for that restaurant

# %%
def rat_gen(reviews):
    # split the one string of reviews into separate reviews using regex
    reviews_sep = re.split(r"[\'\"], [\'\"]", reviews)
    # extract the compound score from the polarity score of each review
    total = [sid.polarity_scores(sentence)["compound"] for sentence in reviews_sep]
    # calculate average
    avg = sum(total)/len(total)
    # calculate rating using formula given above
    rating = round((10 * (avg + 0.9623) / (1.9533)), ndigits=2)
    return rating

# %% [markdown]
# `rest_data_rating` will be merged to `dirty` so that the `reviews_list` column gets added

# %%
dirty = pd.merge(dirty, rest_data_rating, on = "restaurant_id", how = "left")
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  \
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               7.66            3.0872
# 4               9.72            3.7126
#
#                                         reviews_list
# 0  ['ambience: 4/5. food: 4/5. have been looking ...
# 1  ['for those looking for good poori-bhaji optio...
# 2  ['for those looking for good poori-bhaji optio...
# 3  ['ambience: 4/5. food: 4/5. have been looking ...
# 4  ['mind blowing quality quantity and taste of t...

# %% [markdown]
# The `restaurant_rating` column values will now be updated by applying the `rat_gen` function to the `reviews_list` column

# %%
dirty["restaurant_rating"] = dirty["reviews_list"].apply(rat_gen)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  \
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126
#
#                                         reviews_list
# 0  ['ambience: 4/5. food: 4/5. have been looking ...
# 1  ['for those looking for good poori-bhaji optio...
# 2  ['for those looking for good poori-bhaji optio...
# 3  ['ambience: 4/5. food: 4/5. have been looking ...
# 4  ['mind blowing quality quantity and taste of t...

# %% [markdown]
# Let's verify that we now have five unique ratings

# %%
len(dirty["restaurant_rating"].unique())
# Out:
# 5

# %%
new_ratings = dirty.groupby(dirty["restaurant_id"])["restaurant_rating"].unique()
new_ratings
# Out:
# restaurant_id
# REST0936    [9.58]
# REST1450    [7.71]
# REST1781    [8.27]
# REST1801    [9.72]
# REST1858    [7.06]
# Name: restaurant_rating, dtype: object

# %% [markdown]
# We can verify that the new ratings generated are correct as they all correspond to the first rating for each restaurant prior to the adjustment

# %%
original_ratings
# Out:
# restaurant_id
# REST0936    [9.58, 7.66]
# REST1450    [7.71, 6.17]
# REST1781    [8.27, 6.62]
# REST1801    [9.72, 7.78]
# REST1858    [7.06, 5.65]
# Name: restaurant_rating, dtype: object

# %% [markdown]
# We now have five unique ratings corresponding to the five unique restaurants
#
# We can now drop the `reviews_list` column

# %%
dirty.drop(columns = "reviews_list", inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126

# %% [markdown]
# ### 3.3 customer_lat and customer_lon
#
# To find any errors in `customer_lat` and `customer_lon`, histograms of the values for each will be plotted

# %%
dirty["customer_lat"].hist()
# Out:
# <AxesSubplot:>

# %%
dirty["customer_lon"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that there are some observations with a latitude greater than 0 and a longitude smaller than 100. Let's retrieve the rows that have either a large `customer_lat` or a small `customer_lon`.
#
# First we will create a mask filter that will return the rows where either `customer_lat` is greater than 0 or `customer_lon` is less than 100

# %%
mask = (dirty["customer_lat"] > 0) | (dirty["customer_lon"] < 100)
dirty[mask]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 165  ORD181709      REST0936   CUST11503   COUR1573    144.935393
# 252  ORD012698      REST1801   CUST06238   COUR1319    144.938188
# 314  ORD262010      REST1450   CUST09653   COUR4840    145.004298
# 351  ORD045760      REST1781   CUST06188   COUR1891    144.935278
# 391  ORD001687      REST1781   CUST00754   COUR3526    144.961922
# 468  ORD170532      REST1450   CUST00924   COUR3405    144.961374
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 165    -37.804583  2020-03-02  05:56:02             0           0
# 252    -37.815714  2020-11-13  20:34:17             0           0
# 314    -37.801484  2020-04-29  15:41:32             0           0
# 351    -37.814246  2020-04-29  20:22:25             0           0
# 391    -37.812975  2020-09-21  13:19:07             1           0
# 468    -37.811408  2020-02-23  21:05:56             0           1
#
#     carrier_vehicle                                      shopping_cart  \
# 165             Car  [('begun pora', 3), ('banana chips', 3), ('che...
# 252             Car                 [('naan', 1), ('panner tikka', 3)]
# 314       Motorbike  [('rasgulla', 2), ('puri sabzi', 3), ('samosa'...
# 351             Car  [('chicken burger', 2), ('mango salad', 2), ('...
# 391       Motorbike   [('burgers', 3), ('peri peri chicken wings', 3)]
# 468             Car  [('poha', 3), ('jalebi', 3), ('puri sabzi', 2)...
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 165                0      156.720                            713
# 252                0       31.300                           3175
# 314                0      161.600                           5652
# 351                0       87.580                           3271
# 391               45       39.353                            526
# 468                0      116.640                           1353
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 165                    2               9.58            3.0461
# 252                    8               9.72            3.4494
# 314                   11               7.71            4.0566
# 351                    8               8.27            3.5276
# 391                    1               8.27            4.0631
# 468                    3               7.71            4.0715

# %% [markdown]
# It seems that for these six rows, the `customer_lat` and `customer_lon` values were swapped due to data entry error. The values will have to be swapped to the correct columns.

# %%
dirty.loc[mask, "customer_lat"], dirty.loc[mask, "customer_lon"] = dirty.loc[mask, "customer_lon"], dirty.loc[mask, "customer_lat"]

# %% [markdown]
# Check that the incorrect rows are now correct:

# %%
dirty[mask]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 165  ORD181709      REST0936   CUST11503   COUR1573    -37.804583
# 252  ORD012698      REST1801   CUST06238   COUR1319    -37.815714
# 314  ORD262010      REST1450   CUST09653   COUR4840    -37.801484
# 351  ORD045760      REST1781   CUST06188   COUR1891    -37.814246
# 391  ORD001687      REST1781   CUST00754   COUR3526    -37.812975
# 468  ORD170532      REST1450   CUST00924   COUR3405    -37.811408
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 165    144.935393  2020-03-02  05:56:02             0           0
# 252    144.938188  2020-11-13  20:34:17             0           0
# 314    145.004298  2020-04-29  15:41:32             0           0
# 351    144.935278  2020-04-29  20:22:25             0           0
# 391    144.961922  2020-09-21  13:19:07             1           0
# 468    144.961374  2020-02-23  21:05:56             0           1
#
#     carrier_vehicle                                      shopping_cart  \
# 165             Car  [('begun pora', 3), ('banana chips', 3), ('che...
# 252             Car                 [('naan', 1), ('panner tikka', 3)]
# 314       Motorbike  [('rasgulla', 2), ('puri sabzi', 3), ('samosa'...
# 351             Car  [('chicken burger', 2), ('mango salad', 2), ('...
# 391       Motorbike   [('burgers', 3), ('peri peri chicken wings', 3)]
# 468             Car  [('poha', 3), ('jalebi', 3), ('puri sabzi', 2)...
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 165                0      156.720                            713
# 252                0       31.300                           3175
# 314                0      161.600                           5652
# 351                0       87.580                           3271
# 391               45       39.353                            526
# 468                0      116.640                           1353
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 165                    2               9.58            3.0461
# 252                    8               9.72            3.4494
# 314                   11               7.71            4.0566
# 351                    8               8.27            3.5276
# 391                    1               8.27            4.0631
# 468                    3               7.71            4.0715

# %%
dirty[(dirty["customer_lat"] > 0) | (dirty["customer_lon"] < 100)]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges]
# Index: []

# %% [markdown]
# Check histograms of both measurements are correct:

# %%
dirty["customer_lat"].hist()
# Out:
# <AxesSubplot:>

# %%
dirty["customer_lon"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The values are now in their respective correct columns

# %% [markdown]
# Check that we have 491 unique latitudes and longitudes corresponding to 491 unique customers as indicated by the `describe` function performed in the beginning of the report

# %%
print("unique customers:   ", len(dirty["customer_id"].unique()))
print("unique customer_lat:", len(dirty["customer_lat"].unique()))
print("unique customer_lon:", len(dirty["customer_lon"].unique()))
# Out:
# unique customers:    491
# unique customer_lat: 491
# unique customer_lon: 491

# %% [markdown]
# ### 3.4 date
#
# The first check for the date column is using regex to make sure all the dates are:
# - in the correct format
# - a valid date
#
# the pattern is
#
# **(2020-(?:(?:02-(?:0[1-9]|[12][0-9]))|(?:(?:0[469]|11)-(?:0[1-9]|[12][0-9]|30))|(?:(?:0[13578]|1[02])-(?:0[1-9]|[12][0-9]|31))))**
#
# This pattern ensures that the months have the correct number of days (for example, February has 29, January has 31, April has 30, etc), and it ensures the format is yyyy-mm-dd.
#
# We can find the rows where the `date` value does not match the regex pattern, and is therefore incorrect. The `str.match` function is applied to the `date` column which returns either **True** or **False** for each column

# %%
pattern = r"(2020-(?:(?:02-(?:0[1-9]|[12][0-9]))|(?:(?:0[469]|11)-(?:0[1-9]|[12][0-9]|30))|(?:(?:0[13578]|1[02])-(?:0[1-9]|[12][0-9]|3[01]))))"

# %%
dirty[~dirty["date"].str.match(pattern)]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 28   ORD164581      REST0936   CUST13029   COUR3493    -37.812418
# 178  ORD130029      REST1781   CUST03640   COUR2087    -37.803909
# 182  ORD279508      REST1858   CUST04864   COUR0281    -37.822144
# 217  ORD101247      REST1450   CUST01738   COUR1494    -37.823158
# 250  ORD348835      REST1858   CUST02073   COUR0852    -37.800866
# 357  ORD142887      REST1781   CUST09517   COUR2817    -37.810926
# 376  ORD242662      REST1450   CUST06952   COUR4243    -37.806267
# 388  ORD117479      REST1450   CUST02517   COUR2626    -37.815592
# 437  ORD134848      REST1450   CUST03327   COUR1924    -37.803348
# 441  ORD206592      REST1450   CUST13286   COUR2690    -37.822231
#
#      customer_lon                      date      time  is_peak_time  \
# 28     144.953615  Fri Apr 10 00:00:00 2020  14:54:03             0
# 178    144.966883                2020-27-07  00:00:00             0
# 182    144.978328  Fri Jul 10 00:00:00 2020  15:57:21             0
# 217    144.942573                2020-20-08  17:08:34             0
# 250    145.008239                2020-28-01  01:34:56             0
# 357    145.004158                2020-25-12  03:45:29             0
# 376    144.959995  Fri Apr  3 00:00:00 2020  13:11:12             1
# 388    145.005919  Sat Apr 11 00:00:00 2020  15:37:34             0
# 437    144.952644                2020-24-02  21:29:40             0
# 441    144.978232                2020-29-01  10:52:44             0
#
#      is_weekend carrier_vehicle  \
# 28            0            Bike
# 178           0             Car
# 182           0            Bike
# 217           0            Bike
# 250           0            Bike
# 357           0             Car
# 376           0            Bike
# 388           1            Bike
# 437           0            Bike
# 441           0             Car
#
#                                          shopping_cart  coupon_discount  \
# 28           [('mocha chingri', 2), ('cheesecake', 3)]                0
# 178        [('beef burger', 3), ('chicken burger', 3)]               10
# 182                   [('crab toast', 1), ('fish', 2)]               20
# 217                      [('poha', 1), ('kachori', 1)]               20
# 250                [('appam', 1), ('mackerel fry', 3)]                0
# 357  [('pizza', 1), ('beef burger', 1), ('coffee', ...                0
# 376                   [('rasgulla', 3), ('samosa', 2)]               20
# 388  [('rasgulla', 1), ('puri sabzi', 3), ('poha', ...               45
# 437  [('samosa', 2), ('kachori', 2), ('puri sabzi',...               10
# 441               [('rasgulla', 1), ('puri sabzi', 1)]               10
#
#      order_price  shortest_distance_to_customer  travel_time_minutes  \
# 28        76.250                           2574                   13
# 178       56.133                           1454                    3
# 182       31.608                            817                    4
# 217       13.200                           1609                    8
# 250       56.870                           4242                   21
# 357      106.770                           3947                    9
# 376       73.144                           1957                   10
# 388       65.422                           4946                   25
# 437       82.287                           1954                   10
# 441       37.512                           2527                    6
#
#      restaurant_rating  delivery_charges
# 28                9.58            3.7406
# 178               8.27            2.6409
# 182               7.06            3.6197
# 217               7.71            3.7690
# 250               7.06            5.1758
# 357               8.27            3.6344
# 376               7.71            5.1401
# 388               7.71            6.3050
# 437               7.71            3.6797
# 441               7.71            3.4501

# %% [markdown]
# We can see two types of errors in the date column:
# - rows **28, 182 376, and 388** have a completely different format of **day mon d time year**
# - the remaining six rows have swapped day and month locations **yyyy-dd-mm** instead of the correct **yyyy-mm-dd**
#
# Let's first tackle the first type of error. We notice that these date values have a `:` in them

# %%
dirty[dirty["date"].str.contains(":")]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 28   ORD164581      REST0936   CUST13029   COUR3493    -37.812418
# 182  ORD279508      REST1858   CUST04864   COUR0281    -37.822144
# 376  ORD242662      REST1450   CUST06952   COUR4243    -37.806267
# 388  ORD117479      REST1450   CUST02517   COUR2626    -37.815592
#
#      customer_lon                      date      time  is_peak_time  \
# 28     144.953615  Fri Apr 10 00:00:00 2020  14:54:03             0
# 182    144.978328  Fri Jul 10 00:00:00 2020  15:57:21             0
# 376    144.959995  Fri Apr  3 00:00:00 2020  13:11:12             1
# 388    145.005919  Sat Apr 11 00:00:00 2020  15:37:34             0
#
#      is_weekend carrier_vehicle  \
# 28            0            Bike
# 182           0            Bike
# 376           0            Bike
# 388           1            Bike
#
#                                          shopping_cart  coupon_discount  \
# 28           [('mocha chingri', 2), ('cheesecake', 3)]                0
# 182                   [('crab toast', 1), ('fish', 2)]               20
# 376                   [('rasgulla', 3), ('samosa', 2)]               20
# 388  [('rasgulla', 1), ('puri sabzi', 3), ('poha', ...               45
#
#      order_price  shortest_distance_to_customer  travel_time_minutes  \
# 28        76.250                           2574                   13
# 182       31.608                            817                    4
# 376       73.144                           1957                   10
# 388       65.422                           4946                   25
#
#      restaurant_rating  delivery_charges
# 28                9.58            3.7406
# 182               7.06            3.6197
# 376               7.71            5.1401
# 388               7.71            6.3050

# %% [markdown]
# We will now replace these values with the correct format. First, we will pass the above filter into a mask variable, then the `date` of the above rows will be converted to datetime using `pd.to_datetime`. To convert them back to string to match the remaining `date` values in the column, we will apply `strftime` from the `datetime` library

# %%
mask = dirty["date"].str.contains(":")
dirty.loc[mask, "date"] = pd.to_datetime(dirty.loc[mask, "date"]).dt.strftime("%Y-%m-%d")

# %%
dirty[mask]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 28   ORD164581      REST0936   CUST13029   COUR3493    -37.812418
# 182  ORD279508      REST1858   CUST04864   COUR0281    -37.822144
# 376  ORD242662      REST1450   CUST06952   COUR4243    -37.806267
# 388  ORD117479      REST1450   CUST02517   COUR2626    -37.815592
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 28     144.953615  2020-04-10  14:54:03             0           0
# 182    144.978328  2020-07-10  15:57:21             0           0
# 376    144.959995  2020-04-03  13:11:12             1           0
# 388    145.005919  2020-04-11  15:37:34             0           1
#
#     carrier_vehicle                                      shopping_cart  \
# 28             Bike          [('mocha chingri', 2), ('cheesecake', 3)]
# 182            Bike                   [('crab toast', 1), ('fish', 2)]
# 376            Bike                   [('rasgulla', 3), ('samosa', 2)]
# 388            Bike  [('rasgulla', 1), ('puri sabzi', 3), ('poha', ...
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 28                 0       76.250                           2574
# 182               20       31.608                            817
# 376               20       73.144                           1957
# 388               45       65.422                           4946
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 28                    13               9.58            3.7406
# 182                    4               7.06            3.6197
# 376                   10               7.71            5.1401
# 388                   25               7.71            6.3050

# %% [markdown]
# The `date` values in the above rows are now correct.
#
# The remaining rows with the second type of error are given below:

# %%
dirty[~dirty["date"].str.match(pattern)]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 178  ORD130029      REST1781   CUST03640   COUR2087    -37.803909
# 217  ORD101247      REST1450   CUST01738   COUR1494    -37.823158
# 250  ORD348835      REST1858   CUST02073   COUR0852    -37.800866
# 357  ORD142887      REST1781   CUST09517   COUR2817    -37.810926
# 437  ORD134848      REST1450   CUST03327   COUR1924    -37.803348
# 441  ORD206592      REST1450   CUST13286   COUR2690    -37.822231
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 178    144.966883  2020-27-07  00:00:00             0           0
# 217    144.942573  2020-20-08  17:08:34             0           0
# 250    145.008239  2020-28-01  01:34:56             0           0
# 357    145.004158  2020-25-12  03:45:29             0           0
# 437    144.952644  2020-24-02  21:29:40             0           0
# 441    144.978232  2020-29-01  10:52:44             0           0
#
#     carrier_vehicle                                      shopping_cart  \
# 178             Car        [('beef burger', 3), ('chicken burger', 3)]
# 217            Bike                      [('poha', 1), ('kachori', 1)]
# 250            Bike                [('appam', 1), ('mackerel fry', 3)]
# 357             Car  [('pizza', 1), ('beef burger', 1), ('coffee', ...
# 437            Bike  [('samosa', 2), ('kachori', 2), ('puri sabzi',...
# 441             Car               [('rasgulla', 1), ('puri sabzi', 1)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 178               10       56.133                           1454
# 217               20       13.200                           1609
# 250                0       56.870                           4242
# 357                0      106.770                           3947
# 437               10       82.287                           1954
# 441               10       37.512                           2527
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 178                    3               8.27            2.6409
# 217                    8               7.71            3.7690
# 250                   21               7.06            5.1758
# 357                    9               8.27            3.6344
# 437                   10               7.71            3.6797
# 441                    6               7.71            3.4501

# %% [markdown]
# We will apply a lambda function to the incorrect values in the `date` column where the date will be split on `-` and reordered to where the format is year-month-day like so:
#
# - Original date: 2020-27-07
# - Split on "-": [2020, 27, 07]
# - Reorder through indexing: [2020, 27, 07][0]-[2020, 27, 07][2]-[2020, 27, 07][1]
# - Output: 2020-07-27

# %%
# set mask
mask = ~dirty["date"].str.match(pattern)

# %%
dirty.loc[mask, "date"] = dirty.loc[mask, "date"].apply(lambda x: f"{x.split('-')[0]}-{x.split('-')[2]}-{x.split('-')[1]}")

# %% [markdown]
# Let's double check our work

# %%
dirty[~dirty["date"].str.match(pattern)]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges]
# Index: []

# %% [markdown]
# We have no more incorrect dates

# %% [markdown]
# ### 3.5 is_peak_time
#
# First, we will check if any value exists in this column other than 0 or 1

# %%
print(dirty["is_peak_time"].unique())
# Out:
# [0 1]

# %% [markdown]
# We can see that indeed only 0 or 1 exist in this column.
#
# Next, we will check the values of `is_peak_time` against the `time` column to check whether the time in each row was indeed inside or outside the peak time. The peak periods are the intervals **12:00:00pm - 1:59:59pm** and **6:00:00pm - 7:59:59pm**
#
# We will pass the filter of peak times into a `mask` variable

# %%
mask = (((dirty["time"] >= "12:00:00") & (dirty["time"] < "14:00:00")) | ((dirty["time"] >= "18:00:00") & (dirty["time"] < "20:00:00")))

# %% [markdown]
# Now we will check if any `is_peak_time` is equal to 0 during the peak times

# %%
dirty[mask & (dirty["is_peak_time"] == 0)]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 300  ORD126860      REST1450   CUST05292   COUR4191    -37.817687
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 300     144.96925  2020-03-30  12:15:49             0           0
#
#     carrier_vehicle                                    shopping_cart  \
# 300             Car  [('jalebi', 2), ('rasgulla', 1), ('samosa', 1)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 300               45       30.184                           1702
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 300                    4               7.71            4.9958

# %% [markdown]
# ORD126860's `is_peak_time` is incorrectly coded as 0. We will recode it as 1

# %%
dirty.loc[mask & (dirty["is_peak_time"] == 0), "is_peak_time"] = 1

# %%
dirty.loc[300, "is_peak_time"]
# Out:
# 1

# %% [markdown]
# Similarly, we will check if any `is_peak_time` is equal to 1 outside of peak times

# %%
dirty[~mask & (dirty["is_peak_time"] == 1)]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 51   ORD211923      REST0936   CUST12798   COUR0931    -37.798980
# 194  ORD347127      REST1450   CUST13323   COUR2311    -37.821925
# 315  ORD012070      REST1801   CUST12386   COUR4253    -37.807347
# 330  ORD316357      REST1801   CUST08580   COUR2857    -37.813174
# 459  ORD161198      REST1450   CUST05594   COUR3213    -37.815204
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 51     144.945435  2020-11-20  06:39:33             1           0
# 194    144.937583  2020-03-09  15:09:53             1           0
# 315    144.945522  2020-05-20  20:06:35             1           0
# 330    144.944975  2020-06-19  02:58:01             1           0
# 459    144.936492  2020-01-22  04:32:58             1           0
#
#     carrier_vehicle                                      shopping_cart  \
# 51              Car  [('tender coconut ice cream', 1), ('paratha', ...
# 194       Motorbike  [('jalebi', 3), ('samosa', 3), ('kachori', 3),...
# 315             Car  [('chicken boneless biryani', 3), ('crispy chi...
# 330            Bike  [('crispy chicken', 3), ('chicken boneless bir...
# 459            Bike  [('puri sabzi', 2), ('rasgulla', 1), ('poha', 1)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 51                 0       95.930                           1936
# 194               20       94.464                           2068
# 315                0      105.700                           2138
# 330               10      109.179                           2672
# 459               20       55.800                           2145
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 51                     5               9.58            3.1352
# 194                    4               7.71            3.5452
# 315                    5               9.72            3.0101
# 330                   13               9.72            3.8407
# 459                   11               7.71            3.7313

# %% [markdown]
# The above orders have been incorrectly coded as 1. They will be corrected to 0

# %%
dirty.loc[~mask & (dirty["is_peak_time"] == 1), "is_peak_time"] = 0

# %%
dirty.loc[[51, 194, 315, 330, 459], "is_peak_time"]
# Out:
# 51     0
# 194    0
# 315    0
# 330    0
# 459    0
# Name: is_peak_time, dtype: int64

# %% [markdown]
# We will perform one final check

# %%
dirty[(mask & (dirty["is_peak_time"] == 0)) | (~mask & (dirty["is_peak_time"] == 1))]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges]
# Index: []

# %% [markdown]
# All `is_peak_time` values are correctly coded now

# %% [markdown]
# ### 3.6 is_weekend
#
# First, we will check if any values exist in this column other than 0 or 1

# %%
print(dirty["is_weekend"].unique())
# Out:
# [1 0]

# %% [markdown]
# We can see that indeed only 0 or 1 exist in this column.
#
# Next, we will check the `is_weekend` values against `date` to verify that the date is in fact a weekend. To accomplish this, we will first create a new temporary `day` column that contains the `date` column values converted to datetime using the `datetime` library

# %%
dirty["day"] = pd.to_datetime(dirty["date"])
dirty["day"].head()
# Out:
# 0   2020-06-20
# 1   2020-12-18
# 2   2020-02-17
# 3   2020-03-26
# 4   2020-05-02
# Name: day, dtype: datetime64[ns]

# %% [markdown]
# Next, we will retrieve the name of the day using the `day_name` function from the `datetime` library

# %%
dirty["day"]= dirty["day"].dt.day_name()
dirty["day"].head()
# Out:
# 0    Saturday
# 1      Friday
# 2      Monday
# 3    Thursday
# 4    Saturday
# Name: day, dtype: object

# %% [markdown]
# Now we can check whether any `is_weekend` values were incorrectly coded. A cross-tabulation of `day` vs `is_weekend` will be generated to check

# %%
pd.crosstab(dirty["day"],dirty["is_weekend"])
# Out:
# is_weekend   0   1
# day
# Friday      74   1
# Monday      68   1
# Saturday     0  67
# Sunday       0  72
# Thursday    71   2
# Tuesday     70   0
# Wednesday   73   1

# %% [markdown]
# We can see that Friday, Monday, Thursday, and Wednesday were incorrectly coded as weekends on some occasions.
#
# We will pass the weekend filter into a mask variable

# %%
mask = ((dirty["day"] == "Saturday") | (dirty["day"] == "Sunday"))
dirty[mask].head()
# Out:
#      order_id restaurant_id customer_id carrier_id  customer_lat  \
# 0   ORD057034      REST0936   CUST13295   COUR1776    -37.822927
# 4   ORD340665      REST1801   CUST05997   COUR0969    -37.806474
# 5   ORD072108      REST1858   CUST07693   COUR4555    -37.812450
# 9   ORD023573      REST0936   CUST07132   COUR3736    -37.802534
# 14  ORD170383      REST1450   CUST04245   COUR4616    -37.824742
#
#     customer_lon        date      time  is_peak_time  is_weekend  \
# 0     144.980852  2020-06-20  17:24:23             0           1
# 4     144.966435  2020-05-02  08:34:17             0           1
# 5     145.011044  2020-08-08  00:11:52             0           1
# 9     144.944545  2020-06-07  14:22:25             0           1
# 14    144.989913  2020-01-18  02:34:17             0           1
#
#    carrier_vehicle                                      shopping_cart  \
# 0        Motorbike  [('cheesecake', 2), ('tender coconut ice cream...
# 4        Motorbike  [('tandoori chicken', 2), ('hyderabadi biryani...
# 5        Motorbike  [('appam', 2), ('kerala parotta', 3), ('macker...
# 9        Motorbike  [('begun pora', 3), ('banana chips', 3), ('che...
# 14             Car  [('puri sabzi', 1), ('poha', 2), ('kachori', 2...
#
#     coupon_discount  order_price  shortest_distance_to_customer  \
# 0                 0      122.080                           5413
# 4                 0       60.720                           1235
# 5                45       58.267                           3402
# 9                10      158.391                           1511
# 14                0       78.310                           3561
#
#     travel_time_minutes  restaurant_rating  delivery_charges       day
# 0                    11               9.58            4.7296  Saturday
# 4                     2               9.72            3.7126  Saturday
# 5                     7               7.06            4.8615  Saturday
# 9                     3               9.58            4.1428    Sunday
# 14                    9               7.71            4.8610  Saturday

# %% [markdown]
# The weekdays that have been incorrectly recorded as weekends will be corrected

# %%
dirty.loc[~mask & (dirty["is_weekend"] == 1), "is_weekend"] = 0

# %% [markdown]
# We will perform one final check

# %%
pd.crosstab(dirty["day"],dirty["is_weekend"])
# Out:
# is_weekend   0   1
# day
# Friday      75   0
# Monday      69   0
# Saturday     0  67
# Sunday       0  72
# Thursday    73   0
# Tuesday     70   0
# Wednesday   74   0

# %% [markdown]
# All `is_weekend` values are correctly coded. We can now drop the `day` column

# %%
dirty.drop(columns = "day", inplace = True)
dirty.head(5)
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126

# %% [markdown]
# ### 3.7  coupon_discount and order_price
#
# `order_price` is calculated by applying the percentage of `coupon_discount` to the price derived from the order's `shopping_cart`. Therefore, for each order the original price prior to the discount will be calculated, this original price will then be used to derive the price of each item for each restaurant using linear algebra. Since the `order_price` in `dirty` is the column we are verifiying, we will run the process on the `missing` data which contains no errors to derive the item prices, we will then apply those item prices to the `dirty` dataframe to verify our `order_price` column.
#
# #### 3.7.1 Calculate Item Prices
#
# We will create a copy of `missing` to work on with only the required columns

# %%
price_calc_df = missing[["restaurant_id", "shopping_cart", "coupon_discount", "order_price"]].copy()
price_calc_df.head()
# Out:
#   restaurant_id                                      shopping_cart  \
# 0      REST1781        [('beef burger', 3), ('chicken burger', 2)]
# 1      REST1801  [('tandoori chicken', 2), ('chicken guntur', 3...
# 2      REST1781  [('veggie pizza', 2), ('chicken burger', 3), (...
# 3      REST1801  [('crispy chicken', 3), ('naan', 1), ('tandoor...
# 4      REST1450  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...
#
#    coupon_discount  order_price
# 0               20       40.360
# 1               10       70.839
# 2               20       64.600
# 3               10      110.853
# 4               40       58.146

# %% [markdown]
# Now we will create a new column `original_price` that contains the price of each order prior to applying `coupon_discount`. The original price is calculated using the following formula:
#
# **original_price = order_price / (1 - (coupon_discount / 100))**

# %%
price_calc_df["original_price"] = round(price_calc_df["order_price"] / (1 - (price_calc_df["coupon_discount"] / 100)), 2)
price_calc_df.head()
# Out:
#   restaurant_id                                      shopping_cart  \
# 0      REST1781        [('beef burger', 3), ('chicken burger', 2)]
# 1      REST1801  [('tandoori chicken', 2), ('chicken guntur', 3...
# 2      REST1781  [('veggie pizza', 2), ('chicken burger', 3), (...
# 3      REST1801  [('crispy chicken', 3), ('naan', 1), ('tandoor...
# 4      REST1450  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...
#
#    coupon_discount  order_price  original_price
# 0               20       40.360           50.45
# 1               10       70.839           78.71
# 2               20       64.600           80.75
# 3               10      110.853          123.17
# 4               40       58.146           96.91

# %% [markdown]
# Using the function `literal_eval` from the `ast` package ([source](https://www.codegrepper.com/code-examples/python/python+extract+list+from+string)), we can convert the string which contains the list of items under `shopping_cart` into a pure list as so:

# %%
price_calc_df.loc[0, "shopping_cart"]
# Out:
# "[('beef burger', 3), ('chicken burger', 2)]"

# %%
# type before applying literal_eval
type(price_calc_df.loc[0, "shopping_cart"])
# Out:
# str

# %%
# type after applying literal_eval
type(literal_eval(price_calc_df.loc[0, "shopping_cart"]))
# Out:
# list

# %%
price_calc_df["shopping_cart"] = price_calc_df["shopping_cart"].apply(literal_eval)
price_calc_df.head()
# Out:
#   restaurant_id                                      shopping_cart  \
# 0      REST1781            [(beef burger, 3), (chicken burger, 2)]
# 1      REST1801  [(tandoori chicken, 2), (chicken guntur, 3), (...
# 2      REST1781  [(veggie pizza, 2), (chicken burger, 3), (beef...
# 3      REST1801  [(crispy chicken, 3), (naan, 1), (tandoori chi...
# 4      REST1450  [(poha, 3), (jalebi, 3), (puri sabzi, 1), (ras...
#
#    coupon_discount  order_price  original_price
# 0               20       40.360           50.45
# 1               10       70.839           78.71
# 2               20       64.600           80.75
# 3               10      110.853          123.17
# 4               40       58.146           96.91

# %% [markdown]
# We will build a dictionary containing the menu for each restaurant and the price for each item. Initially, the price for all the items will be set to 0

# %%
rest_menu = {}

# iterate over unique restaurants in restaurant_id
for rest in price_calc_df["restaurant_id"].unique():
    # create temporary dataframe containing only current restaurant_id
    temp_df = price_calc_df[price_calc_df["restaurant_id"] == rest].copy()   
    # for each row under shopping_cart, extract the first item from each tuple in that shopping cart.
    # place inside set to only have unique items
    menu = {item[0] for cart in temp_df["shopping_cart"] for item in cart}
    # create dictionary of items and price
    menu_prices = {item: 0 for item in menu}
    # insert restaurant_id as key and the menu as the value
    rest_menu[rest] = menu_prices
    
rest_menu
# Out:
# {'REST1781': {'coffee': 0,
#   'beef burger': 0,
#   'pizza': 0,
#   'mango salad': 0,
#   'veggie pizza': 0,
#   'burgers': 0,
#   'peri peri chicken wings': 0,
#   'chicken burger': 0},
#  'REST1801': {'tandoori chicken': 0,
#   'hyderabadi biryani': 0,
#   'chicken boneless biryani': 0,
#   'panner tikka': 0,
#   'chicken guntur': 0,
#   'naan': 0,
#   'crispy chicken': 0},
#  'REST1450': {'puri sabzi': 0,
#   'poha': 0,
#   'rasgulla': 0,
#   'jalebi': 0,
#   'kachori': 0,
#   'samosa': 0},
#  'REST1858': {'fish': 0,
#   'roast beef': 0,
#   'crab toast': 0,
#   'mackerel fry': 0,
#   'beef fry': 0,
#   'appam': 0,
#   'kerala parotta': 0},
#  'REST0936': {'cheesecake': 0,
#   'saffron pilaf': 0,
#   'paratha': 0,
#   'begun pora': 0,
#   'tender coconut ice cream': 0,
#   'banana chips': 0,
#   'mocha chingri': 0}}

# %% [markdown]
# To calculate the price of each item for each restaurant, will need to use a linear system of equations. To calculate the first few items for each restaurant, we will need to find two orders with the same menu items and plug them into our linear system. To be able to find orders with the same menu items, we will create a new column `basket_set` that contains the menu items from each order. It will be placed inside a set so that the order of the items doesn't matter when making comparisons

# %%
price_calc_df["basket_set"] = price_calc_df["shopping_cart"].apply(lambda x: {item[0] for item in x})
price_calc_df.head()
# Out:
#   restaurant_id                                      shopping_cart  \
# 0      REST1781            [(beef burger, 3), (chicken burger, 2)]
# 1      REST1801  [(tandoori chicken, 2), (chicken guntur, 3), (...
# 2      REST1781  [(veggie pizza, 2), (chicken burger, 3), (beef...
# 3      REST1801  [(crispy chicken, 3), (naan, 1), (tandoori chi...
# 4      REST1450  [(poha, 3), (jalebi, 3), (puri sabzi, 1), (ras...
#
#    coupon_discount  order_price  original_price  \
# 0               20       40.360           50.45
# 1               10       70.839           78.71
# 2               20       64.600           80.75
# 3               10      110.853          123.17
# 4               40       58.146           96.91
#
#                                           basket_set
# 0                      {beef burger, chicken burger}
# 1   {tandoori chicken, chicken guntur, panner tikka}
# 2        {veggie pizza, beef burger, chicken burger}
# 3  {hyderabadi biryani, tandoori chicken, naan, c...
# 4               {jalebi, rasgulla, puri sabzi, poha}

# %% [markdown]
# For each restaurant now, we will generate the value_counts of `basket_set` to show the number of times the same `basket_set` is present. We will then pick the set with the largest number of repitions, that contains the same number of items as the number of repitions to simultaneously calculate as many items as possible using the linear system of equations. We will start with `restaurant_id` **1781**

# %%
# create new dataframe filtered for REST1781
price_calc_df_1781 = price_calc_df[price_calc_df["restaurant_id"] == "REST1781"].copy()
price_calc_df_1781.head()
# Out:
#    restaurant_id                                      shopping_cart  \
# 0       REST1781            [(beef burger, 3), (chicken burger, 2)]
# 2       REST1781  [(veggie pizza, 2), (chicken burger, 3), (beef...
# 5       REST1781            [(burgers, 3), (coffee, 2), (pizza, 1)]
# 16      REST1781  [(beef burger, 2), (pizza, 2), (peri peri chic...
# 18      REST1781                    [(veggie pizza, 3), (pizza, 2)]
#
#     coupon_discount  order_price  original_price  \
# 0                20       40.360           50.45
# 2                20       64.600           80.75
# 5                10       77.733           86.37
# 16                0      119.350          119.35
# 18               10       67.203           74.67
#
#                                        basket_set
# 0                   {beef burger, chicken burger}
# 2     {veggie pizza, beef burger, chicken burger}
# 5                        {coffee, burgers, pizza}
# 16  {beef burger, pizza, peri peri chicken wings}
# 18                          {veggie pizza, pizza}

# %%
# generate REST1781 menu for reference
rest_menu["REST1781"]
# Out:
# {'coffee': 0,
#  'beef burger': 0,
#  'pizza': 0,
#  'mango salad': 0,
#  'veggie pizza': 0,
#  'burgers': 0,
#  'peri peri chicken wings': 0,
#  'chicken burger': 0}

# %%
# generate value_counts for basket_set
price_calc_df_1781["basket_set"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'set'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'set'
# {peri peri chicken wings, chicken burger}                              5
# {veggie pizza, pizza}                                                  4
# {beef burger, chicken burger}                                          3
# {mango salad, beef burger, chicken burger}                             3
# {coffee, pizza}                                                        3
# {veggie pizza, beef burger, chicken burger}                            2
# {veggie pizza, beef burger, pizza}                                     2
# {coffee, beef burger, peri peri chicken wings}                         2
# {veggie pizza, mango salad, beef burger}                               2
# {beef burger, pizza}                                                   2
# {mango salad, burgers}                                                 2
# {coffee, pizza, mango salad, chicken burger}                           2
# {coffee, beef burger}                                                  2
# {coffee, burgers, pizza}                                               2
# {veggie pizza, mango salad}                                            2
# {mango salad, burgers, peri peri chicken wings, chicken burger}        1
# {veggie pizza, beef burger, pizza, peri peri chicken wings}            1
# {mango salad, beef burger, burgers, peri peri chicken wings}           1
# {coffee, beef burger, pizza, peri peri chicken wings}                  1
# {veggie pizza, coffee, burgers, chicken burger}                        1
# {veggie pizza, chicken burger}                                         1
# {beef burger, burgers, pizza}                                          1
# {veggie pizza, beef burger, burgers, pizza}                            1
# {mango salad, beef burger}                                             1
# {pizza, peri peri chicken wings, chicken burger}                       1
# {coffee, beef burger, peri peri chicken wings, mango salad}            1
# {veggie pizza, burgers}                                                1
# {veggie pizza, mango salad, pizza, beef burger}                        1
# {burgers, peri peri chicken wings, chicken burger}                     1
# {mango salad, beef burger, peri peri chicken wings, chicken burger}    1
# {mango salad, pizza}                                                   1
# {veggie pizza, coffee, burgers}                                        1
# {beef burger, peri peri chicken wings}                                 1
# {coffee, burgers}                                                      1
# {mango salad, burgers, pizza}                                          1
# {veggie pizza, burgers, peri peri chicken wings, chicken burger}       1
# {coffee, beef burger, peri peri chicken wings, chicken burger}         1
# {veggie pizza, beef burger}                                            1
# {beef burger, pizza, peri peri chicken wings}                          1
# {veggie pizza, mango salad, pizza}                                     1
# {veggie pizza, coffee, pizza, chicken burger}                          1
# {veggie pizza, coffee, beef burger, burgers}                           1
# {mango salad, coffee, chicken burger}                                  1
# {veggie pizza, mango salad, peri peri chicken wings}                   1
# {pizza, burgers}                                                       1
# {beef burger, burgers}                                                 1
# {veggie pizza, burgers, chicken burger}                                1
# {veggie pizza, peri peri chicken wings}                                1
# {veggie pizza, coffee}                                                 1
# {mango salad, burgers, peri peri chicken wings}                        1
# {mango salad, burgers, pizza, peri peri chicken wings}                 1
# {veggie pizza, peri peri chicken wings, chicken burger}                1
# {coffee, burgers, beef burger, chicken burger}                         1
# {coffee, pizza, burgers, chicken burger}                               1
# {mango salad, pizza, coffee}                                           1
# {beef burger, burgers, pizza, chicken burger}                          1
# {veggie pizza, coffee, beef burger, peri peri chicken wings}           1
# {mango salad, burgers, chicken burger}                                 1
# {mango salad, peri peri chicken wings}                                 1
# Name: basket_set, dtype: int64

# %% [markdown]
# We will first choose the set {beef burger, mango salad, chicken burger} as it is the set with the highest repitions with the same number of items (3).
#
# Retrieve the rows with that set to choose from

# %%
price_calc_df_1781[price_calc_df_1781["basket_set"] == {"beef burger", "mango salad", "chicken burger"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 293      REST1781  [(chicken burger, 3), (mango salad, 2), (beef ...
# 325      REST1781  [(mango salad, 3), (chicken burger, 3), (beef ...
# 458      REST1781  [(beef burger, 1), (mango salad, 3), (chicken ...
#
#      coupon_discount  order_price  original_price  \
# 293                0       90.630           90.63
# 325                0      122.500          122.50
# 458               45       49.385           89.79
#
#                                      basket_set
# 293  {mango salad, beef burger, chicken burger}
# 325  {mango salad, beef burger, chicken burger}
# 458  {mango salad, beef burger, chicken burger}

# %% [markdown]
# We will extract the `shopping_cart` column as a list so we can better view the carts

# %%
list(price_calc_df_1781[price_calc_df_1781["basket_set"] == {"beef burger", "mango salad", "chicken burger"}]["shopping_cart"])
# Out:
# [[('chicken burger', 3), ('mango salad', 2), ('beef burger', 1)],
#  [('mango salad', 3), ('chicken burger', 3), ('beef burger', 2)],
#  [('beef burger', 1), ('mango salad', 3), ('chicken burger', 1)]]

# %% [markdown]
# We will now plug in the values for each item and the original price into the linear system. We will use the function `linalg.solve` from the `numpy` package

# %%
# enter number of items from each cart where each cart is a separate list into an array
a = np.array([[3, 2, 1], [3, 3, 2], [1, 3, 1]])
# enter original_price for each cart into an array
b = np.array([90.63, 122.5, 89.79])
# solve linear equation
x = np.linalg.solve(a, b)
x
# Out:
# array([11.92, 23.  ,  8.87])

# %%
# set prices of items using unpacking
chicken_burger, mango_salad, beef_burger = x

# %%
# update menu prices
rest_menu["REST1781"]["chicken burger"] = chicken_burger
rest_menu["REST1781"]["mango salad"] = mango_salad
rest_menu["REST1781"]["beef burger"] = beef_burger
rest_menu["REST1781"]
# Out:
# {'coffee': 0,
#  'beef burger': 8.870000000000001,
#  'pizza': 0,
#  'mango salad': 23.000000000000004,
#  'veggie pizza': 0,
#  'burgers': 0,
#  'peri peri chicken wings': 0,
#  'chicken burger': 11.919999999999995}

# %% [markdown]
# We will calculate the prices of the remaining items the same way

# %%
price_calc_df_1781[price_calc_df_1781["basket_set"] == {"pizza", "veggie pizza"}]
# Out:
#     restaurant_id                    shopping_cart  coupon_discount  \
# 18       REST1781  [(veggie pizza, 3), (pizza, 2)]               10
# 31       REST1781  [(pizza, 3), (veggie pizza, 1)]               10
# 158      REST1781  [(veggie pizza, 3), (pizza, 3)]                0
# 162      REST1781  [(veggie pizza, 2), (pizza, 1)]               20
#
#      order_price  original_price             basket_set
# 18        67.203           74.67  {veggie pizza, pizza}
# 31        71.856           79.84  {veggie pizza, pizza}
# 158       98.220           98.22  {veggie pizza, pizza}
# 162       33.544           41.93  {veggie pizza, pizza}

# %%
list(price_calc_df_1781[price_calc_df_1781["basket_set"] == {"pizza", "veggie pizza"}]["shopping_cart"])
# Out:
# [[('veggie pizza', 3), ('pizza', 2)],
#  [('pizza', 3), ('veggie pizza', 1)],
#  [('veggie pizza', 3), ('pizza', 3)],
#  [('veggie pizza', 2), ('pizza', 1)]]

# %%
a = np.array([[3, 2], [1, 3]])
b = np.array([74.67, 79.84])
x = np.linalg.solve(a, b)
veggie_pizza, pizza = x
rest_menu["REST1781"]["veggie pizza"] = veggie_pizza
rest_menu["REST1781"]["pizza"] = pizza

# %% [markdown]
# For the remaining items, we can solve the equation if we know the price of the other item in the cart

# %%
price_calc_df_1781[price_calc_df_1781["basket_set"] == {"peri peri chicken wings", "chicken burger"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 115      REST1781  [(chicken burger, 1), (peri peri chicken wings...
# 264      REST1781  [(peri peri chicken wings, 3), (chicken burger...
# 382      REST1781  [(chicken burger, 2), (peri peri chicken wings...
# 425      REST1781  [(peri peri chicken wings, 2), (chicken burger...
# 477      REST1781  [(chicken burger, 3), (peri peri chicken wings...
#
#      coupon_discount  order_price  original_price  \
# 115                0       48.260           48.26
# 264               40       54.162           90.27
# 382                0       60.180           60.18
# 425                0       48.260           48.26
# 477                0       53.930           53.93
#
#                                     basket_set
# 115  {peri peri chicken wings, chicken burger}
# 264  {peri peri chicken wings, chicken burger}
# 382  {peri peri chicken wings, chicken burger}
# 425  {peri peri chicken wings, chicken burger}
# 477  {peri peri chicken wings, chicken burger}

# %%
price_calc_df_1781.loc[115, "shopping_cart"]
# Out:
# [('chicken burger', 1), ('peri peri chicken wings', 2)]

# %% [markdown]
# We already know the price of a chicken burger, so we will plug it in into row 115 and subtract the price from the `original_price` to come up with the price of peri peri chicken wings

# %%
peri_peri = (48.26 - rest_menu["REST1781"]["chicken burger"]) / 2
peri_peri
# Out:
# 18.17

# %%
rest_menu["REST1781"]["peri peri chicken wings"] = peri_peri

# %% [markdown]
# The remaining items will be calculated the same way

# %%
price_calc_df_1781[price_calc_df_1781["basket_set"] == {"coffee", "pizza"}]
# Out:
#     restaurant_id              shopping_cart  coupon_discount  order_price  \
# 39       REST1781  [(coffee, 3), (pizza, 3)]                0      139.320
# 83       REST1781  [(pizza, 2), (coffee, 3)]                0      115.770
# 227      REST1781  [(pizza, 1), (coffee, 3)]               40       55.332
#
#      original_price       basket_set
# 39           139.32  {coffee, pizza}
# 83           115.77  {coffee, pizza}
# 227           92.22  {coffee, pizza}

# %%
price_calc_df_1781.loc[227, "shopping_cart"]
# Out:
# [('pizza', 1), ('coffee', 3)]

# %%
coffee = (92.22 - rest_menu["REST1781"]["pizza"]) / 3
rest_menu["REST1781"]["coffee"] = coffee

# %%
price_calc_df_1781[price_calc_df_1781["basket_set"] == {"mango salad", "burgers"}]
# Out:
#     restaurant_id                     shopping_cart  coupon_discount  \
# 86       REST1781  [(mango salad, 3), (burgers, 2)]               10
# 350      REST1781  [(burgers, 1), (mango salad, 2)]                0
#
#      order_price  original_price              basket_set
# 86        72.324           80.36  {mango salad, burgers}
# 350       51.680           51.68  {mango salad, burgers}

# %%
price_calc_df_1781.loc[350, "shopping_cart"]
# Out:
# [('burgers', 1), ('mango salad', 2)]

# %%
burgers = (51.68 - (2 * rest_menu["REST1781"]["mango salad"]))
rest_menu["REST1781"]["burgers"] = burgers

# %% [markdown]
# We now have the prices for all the items for REST1781

# %%
rest_menu["REST1781"]
# Out:
# {'coffee': 22.89,
#  'beef burger': 8.870000000000001,
#  'pizza': 23.55,
#  'mango salad': 23.000000000000004,
#  'veggie pizza': 9.19,
#  'burgers': 5.679999999999993,
#  'peri peri chicken wings': 18.17,
#  'chicken burger': 11.919999999999995}

# %% [markdown]
# Now we will calculate the item prices for the remaining restaurants using the same process

# %%
price_calc_df_1801 = price_calc_df[price_calc_df["restaurant_id"] == "REST1801"].copy()

# %%
rest_menu["REST1801"]
# Out:
# {'tandoori chicken': 0,
#  'hyderabadi biryani': 0,
#  'chicken boneless biryani': 0,
#  'panner tikka': 0,
#  'chicken guntur': 0,
#  'naan': 0,
#  'crispy chicken': 0}

# %%
price_calc_df_1801["basket_set"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'set'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'set'
# {chicken boneless biryani, naan, crispy chicken}                                    5
# {tandoori chicken, panner tikka}                                                    3
# {crispy chicken, panner tikka}                                                      3
# {chicken guntur, naan, chicken boneless biryani, panner tikka}                      3
# {chicken guntur, chicken boneless biryani}                                          3
# {hyderabadi biryani, chicken guntur, chicken boneless biryani, panner tikka}        3
# {hyderabadi biryani, chicken boneless biryani, tandoori chicken, crispy chicken}    3
# {hyderabadi biryani, chicken boneless biryani, crispy chicken, panner tikka}        2
# {hyderabadi biryani, chicken boneless biryani, crispy chicken}                      2
# {hyderabadi biryani, tandoori chicken, panner tikka}                                2
# {tandoori chicken, chicken boneless biryani, crispy chicken, panner tikka}          2
# {tandoori chicken, chicken guntur, panner tikka}                                    2
# {chicken boneless biryani, naan}                                                    2
# {naan, panner tikka}                                                                2
# {tandoori chicken, hyderabadi biryani, chicken boneless biryani, naan}              2
# {chicken boneless biryani, crispy chicken, panner tikka}                            2
# {hyderabadi biryani, naan, crispy chicken}                                          2
# {tandoori chicken, chicken guntur}                                                  2
# {hyderabadi biryani, naan}                                                          2
# {hyderabadi biryani, chicken boneless biryani, naan}                                2
# {chicken boneless biryani, naan, chicken guntur}                                    2
# {chicken guntur, panner tikka}                                                      2
# {hyderabadi biryani, tandoori chicken, crispy chicken}                              2
# {tandoori chicken, chicken guntur, chicken boneless biryani}                        2
# {chicken guntur, naan}                                                              2
# {crispy chicken, chicken guntur, naan, chicken boneless biryani}                    2
# {hyderabadi biryani, chicken guntur, chicken boneless biryani}                      2
# {chicken boneless biryani, chicken guntur, panner tikka}                            2
# {tandoori chicken, chicken boneless biryani}                                        2
# {chicken guntur, crispy chicken}                                                    1
# {tandoori chicken, chicken guntur, naan}                                            1
# {hyderabadi biryani, chicken guntur, tandoori chicken, chicken boneless biryani}    1
# {tandoori chicken, chicken guntur, naan, panner tikka}                              1
# {chicken guntur, crispy chicken, panner tikka}                                      1
# {hyderabadi biryani, crispy chicken}                                                1
# {tandoori chicken, chicken boneless biryani, naan, panner tikka}                    1
# {hyderabadi biryani, tandoori chicken, chicken guntur, crispy chicken}              1
# {tandoori chicken, naan, crispy chicken, panner tikka}                              1
# {chicken boneless biryani, chicken guntur, crispy chicken, panner tikka}            1
# {hyderabadi biryani, tandoori chicken, chicken guntur, panner tikka}                1
# {hyderabadi biryani, chicken boneless biryani, naan, chicken guntur}                1
# {tandoori chicken, chicken boneless biryani, naan}                                  1
# {hyderabadi biryani, naan, panner tikka}                                            1
# {tandoori chicken, naan, crispy chicken}                                            1
# {hyderabadi biryani, chicken boneless biryani}                                      1
# {hyderabadi biryani, chicken boneless biryani, naan, panner tikka}                  1
# {hyderabadi biryani, chicken guntur}                                                1
# {tandoori chicken, chicken boneless biryani, naan, crispy chicken}                  1
# {hyderabadi biryani, chicken boneless biryani, chicken guntur, crispy chicken}      1
# {hyderabadi biryani, panner tikka}                                                  1
# {chicken boneless biryani, naan, panner tikka}                                      1
# {chicken guntur, naan, panner tikka}                                                1
# {hyderabadi biryani, tandoori chicken, naan}                                        1
# {hyderabadi biryani, chicken guntur, naan, panner tikka}                            1
# {tandoori chicken, naan, panner tikka}                                              1
# {hyderabadi biryani, tandoori chicken, naan, crispy chicken}                        1
# {tandoori chicken, crispy chicken, panner tikka}                                    1
# {chicken boneless biryani, naan, crispy chicken, panner tikka}                      1
# {chicken boneless biryani, panner tikka}                                            1
# {hyderabadi biryani, chicken guntur, naan, crispy chicken}                          1
# Name: basket_set, dtype: int64

# %%
price_calc_df_1801[price_calc_df_1801["basket_set"] == {"naan", "chicken boneless biryani", "crispy chicken"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 55       REST1801  [(chicken boneless biryani, 3), (crispy chicke...
# 171      REST1801  [(chicken boneless biryani, 1), (naan, 2), (cr...
# 180      REST1801  [(chicken boneless biryani, 2), (crispy chicke...
# 327      REST1801  [(chicken boneless biryani, 2), (crispy chicke...
# 342      REST1801  [(crispy chicken, 2), (chicken boneless biryan...
#
#      coupon_discount  order_price  original_price  \
# 55                10       95.850          106.50
# 171                0       61.130           61.13
# 180               45       46.090           83.80
# 327                0      109.410          109.41
# 342               10      118.926          132.14
#
#                                            basket_set
# 55   {chicken boneless biryani, naan, crispy chicken}
# 171  {chicken boneless biryani, naan, crispy chicken}
# 180  {chicken boneless biryani, naan, crispy chicken}
# 327  {chicken boneless biryani, naan, crispy chicken}
# 342  {chicken boneless biryani, naan, crispy chicken}

# %%
list(price_calc_df_1801[price_calc_df_1801["basket_set"] == {"naan", "chicken boneless biryani", "crispy chicken"}]["shopping_cart"])
# Out:
# [[('chicken boneless biryani', 3), ('crispy chicken', 2), ('naan', 1)],
#  [('chicken boneless biryani', 1), ('naan', 2), ('crispy chicken', 1)],
#  [('chicken boneless biryani', 2), ('crispy chicken', 2), ('naan', 1)],
#  [('chicken boneless biryani', 2), ('crispy chicken', 3), ('naan', 2)],
#  [('crispy chicken', 2), ('chicken boneless biryani', 3), ('naan', 3)]]

# %%
a = np.array([[3, 2, 1], [1, 1, 2], [2, 2, 1]])
b = np.array([106.5, 61.13, 83.8])
x = np.linalg.solve(a, b)
chicken_boneless_biryani, crispy_chicken, naan = x
rest_menu["REST1801"]["chicken boneless biryani"] = chicken_boneless_biryani
rest_menu["REST1801"]["crispy chicken"] = crispy_chicken
rest_menu["REST1801"]["naan"] = naan

# %%
price_calc_df_1801[price_calc_df_1801["basket_set"] == {"panner tikka", "tandoori chicken"}]
# Out:
#     restaurant_id                               shopping_cart  \
# 188      REST1801  [(tandoori chicken, 1), (panner tikka, 1)]
# 192      REST1801  [(tandoori chicken, 1), (panner tikka, 1)]
# 240      REST1801  [(panner tikka, 2), (tandoori chicken, 3)]
#
#      coupon_discount  order_price  original_price  \
# 188               10       22.554           25.06
# 192                0       25.060           25.06
# 240                0       69.020           69.02
#
#                            basket_set
# 188  {tandoori chicken, panner tikka}
# 192  {tandoori chicken, panner tikka}
# 240  {tandoori chicken, panner tikka}

# %%
a = np.array([[1, 1], [3, 2]])
b = np.array([25.06, 69.02])
x = np.linalg.solve(a, b)
tandoori_chicken, panner_tikka = x
rest_menu["REST1801"]["tandoori chicken"] = tandoori_chicken
rest_menu["REST1801"]["panner tikka"] = panner_tikka

# %%
price_calc_df_1801[price_calc_df_1801["basket_set"] == {"chicken guntur", "chicken boneless biryani"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 253      REST1801  [(chicken guntur, 2), (chicken boneless biryan...
# 341      REST1801  [(chicken guntur, 1), (chicken boneless biryan...
# 426      REST1801  [(chicken guntur, 3), (chicken boneless biryan...
#
#      coupon_discount  order_price  original_price  \
# 253                0        87.16           87.16
# 341                0        32.23           32.23
# 426                0        73.99           73.99
#
#                                      basket_set
# 253  {chicken guntur, chicken boneless biryani}
# 341  {chicken guntur, chicken boneless biryani}
# 426  {chicken guntur, chicken boneless biryani}

# %%
price_calc_df_1801.loc[341, "shopping_cart"]
# Out:
# [('chicken guntur', 1), ('chicken boneless biryani', 1)]

# %%
chicken_guntur = 32.23 - rest_menu["REST1801"]["chicken boneless biryani"]
rest_menu["REST1801"]["chicken guntur"] = chicken_guntur

# %%
price_calc_df_1801[price_calc_df_1801["basket_set"] == {"naan", "hyderabadi biryani"}]
# Out:
#     restaurant_id                         shopping_cart  coupon_discount  \
# 281      REST1801  [(naan, 2), (hyderabadi biryani, 1)]                0
# 365      REST1801  [(naan, 2), (hyderabadi biryani, 1)]                0
#
#      order_price  original_price                  basket_set
# 281        33.28           33.28  {hyderabadi biryani, naan}
# 365        33.28           33.28  {hyderabadi biryani, naan}

# %%
hyderabadi_biryani = 33.28 - (2 * rest_menu["REST1801"]["naan"])
rest_menu["REST1801"]["hyderabadi biryani"] = hyderabadi_biryani

# %%
rest_menu["REST1801"]
# Out:
# {'tandoori chicken': 18.899999999999995,
#  'hyderabadi biryani': 7.639999999999997,
#  'chicken boneless biryani': 22.700000000000003,
#  'panner tikka': 6.160000000000003,
#  'chicken guntur': 9.529999999999994,
#  'naan': 12.820000000000002,
#  'crispy chicken': 12.789999999999994}

# %%
price_calc_df_1450 = price_calc_df[price_calc_df["restaurant_id"] == "REST1450"].copy()

# %%
rest_menu["REST1450"]
# Out:
# {'puri sabzi': 0,
#  'poha': 0,
#  'rasgulla': 0,
#  'jalebi': 0,
#  'kachori': 0,
#  'samosa': 0}

# %%
price_calc_df_1450["basket_set"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'set'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'set'
# {kachori, puri sabzi, samosa}              6
# {jalebi, rasgulla, puri sabzi, poha}       5
# {jalebi, kachori, puri sabzi}              5
# {poha, rasgulla, puri sabzi}               5
# {jalebi, samosa}                           4
# {poha, rasgulla}                           4
# {poha, puri sabzi, samosa}                 4
# {jalebi, puri sabzi, rasgulla, samosa}     4
# {kachori, rasgulla}                        4
# {puri sabzi, poha}                         4
# {kachori, rasgulla, poha}                  3
# {jalebi, kachori, rasgulla, poha}          3
# {poha, samosa}                             3
# {jalebi, kachori, poha, samosa}            3
# {kachori, puri sabzi, rasgulla, samosa}    3
# {kachori, rasgulla, poha, samosa}          3
# {puri sabzi, rasgulla}                     3
# {kachori, poha}                            3
# {jalebi, puri sabzi}                       3
# {puri sabzi, samosa}                       3
# {jalebi, rasgulla}                         3
# {rasgulla, samosa}                         3
# {jalebi, kachori, poha}                    2
# {jalebi, puri sabzi, rasgulla}             2
# {jalebi, poha, samosa}                     2
# {kachori, puri sabzi, samosa, poha}        2
# {kachori, poha, samosa}                    2
# {jalebi, kachori, rasgulla, samosa}        2
# {kachori, puri sabzi, rasgulla}            2
# {kachori, puri sabzi, poha}                2
# {puri sabzi, rasgulla, poha, samosa}       2
# {jalebi, puri sabzi, samosa}               1
# {jalebi, kachori, rasgulla}                1
# {jalebi, poha, puri sabzi}                 1
# {jalebi, kachori, puri sabzi, poha}        1
# {kachori, poha, rasgulla, puri sabzi}      1
# {jalebi, rasgulla, poha, samosa}           1
# {jalebi, kachori}                          1
# {poha, rasgulla, samosa}                   1
# {jalebi, kachori, puri sabzi, samosa}      1
# {jalebi, kachori, rasgulla, puri sabzi}    1
# {kachori, samosa}                          1
# {jalebi, kachori, samosa}                  1
# {rasgulla, puri sabzi, samosa}             1
# Name: basket_set, dtype: int64

# %%
price_calc_df_1450[price_calc_df_1450["basket_set"] == {"rasgulla", "puri sabzi", "jalebi", "samosa"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 172      REST1450  [(jalebi, 1), (samosa, 2), (rasgulla, 3), (pur...
# 233      REST1450  [(samosa, 2), (jalebi, 2), (puri sabzi, 1), (r...
# 338      REST1450  [(rasgulla, 3), (samosa, 1), (puri sabzi, 1), ...
# 491      REST1450  [(samosa, 1), (rasgulla, 1), (jalebi, 1), (pur...
#
#      coupon_discount  order_price  original_price  \
# 172               45       66.676          121.23
# 233                0      109.350          109.35
# 338                0      108.440          108.44
# 491                0      104.000          104.00
#
#                                  basket_set
# 172  {jalebi, puri sabzi, rasgulla, samosa}
# 233  {jalebi, rasgulla, puri sabzi, samosa}
# 338  {jalebi, puri sabzi, rasgulla, samosa}
# 491  {jalebi, puri sabzi, rasgulla, samosa}

# %%
list(price_calc_df_1450[price_calc_df_1450["basket_set"] == {"rasgulla", "puri sabzi", "jalebi", "samosa"}]["shopping_cart"])
# Out:
# [[('jalebi', 1), ('samosa', 2), ('rasgulla', 3), ('puri sabzi', 1)],
#  [('samosa', 2), ('jalebi', 2), ('puri sabzi', 1), ('rasgulla', 2)],
#  [('rasgulla', 3), ('samosa', 1), ('puri sabzi', 1), ('jalebi', 1)],
#  [('samosa', 1), ('rasgulla', 1), ('jalebi', 1), ('puri sabzi', 3)]]

# %%
a = np.array([[1, 2, 3, 1], [2, 2, 2, 1], [1, 1, 3, 1], [1, 1, 1, 3]])
b = np.array([121.23, 109.35, 108.44, 104])
x = np.linalg.solve(a, b)
jalebi, samosa, rasgulla, puri_sabzi = x
rest_menu["REST1450"]["rasgulla"] = rasgulla
rest_menu["REST1450"]["puri sabzi"] = puri_sabzi
rest_menu["REST1450"]["jalebi"] = jalebi
rest_menu["REST1450"]["samosa"] = samosa

# %%
price_calc_df_1450[price_calc_df_1450["basket_set"] == {"kachori", "poha"}]
# Out:
#     restaurant_id              shopping_cart  coupon_discount  order_price  \
# 269      REST1450  [(kachori, 3), (poha, 1)]               20       26.256
# 345      REST1450  [(kachori, 1), (poha, 2)]               10       22.356
# 398      REST1450  [(kachori, 1), (poha, 2)]                0       24.840
#
#      original_price       basket_set
# 269           32.82  {kachori, poha}
# 345           24.84  {kachori, poha}
# 398           24.84  {kachori, poha}

# %%
a = np.array([[3, 1], [1, 2]])
b = np.array([32.82, 24.84])
x = np.linalg.solve(a, b)
kachori, poha = x
rest_menu["REST1450"]["kachori"] = kachori
rest_menu["REST1450"]["poha"] = poha

# %%
rest_menu["REST1450"]
# Out:
# {'puri sabzi': 19.73,
#  'poha': 8.34,
#  'rasgulla': 21.95,
#  'jalebi': 10.06999999999999,
#  'kachori': 8.16,
#  'samosa': 12.790000000000006}

# %%
price_calc_df_1858 = price_calc_df[price_calc_df["restaurant_id"] == "REST1858"].copy()

# %%
rest_menu["REST1858"]
# Out:
# {'fish': 0,
#  'roast beef': 0,
#  'crab toast': 0,
#  'mackerel fry': 0,
#  'beef fry': 0,
#  'appam': 0,
#  'kerala parotta': 0}

# %%
price_calc_df_1858["basket_set"].value_counts().head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'set'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'set'
# {mackerel fry, roast beef, crab toast}                3
# {beef fry, fish, appam, kerala parotta}               3
# {kerala parotta, roast beef, fish, crab toast}        3
# {appam, crab toast}                                   3
# {appam, crab toast, kerala parotta}                   3
# {fish, appam, kerala parotta}                         3
# {beef fry, roast beef, appam, mackerel fry}           2
# {beef fry, mackerel fry, appam, kerala parotta}       2
# {beef fry, roast beef, mackerel fry}                  2
# {beef fry, roast beef, appam, kerala parotta}         2
# {roast beef, fish, appam, crab toast}                 2
# {fish, kerala parotta}                                2
# {beef fry, roast beef, crab toast, kerala parotta}    2
# {beef fry, mackerel fry, crab toast}                  2
# {beef fry, fish, mackerel fry}                        2
# {beef fry, mackerel fry}                              2
# {roast beef, crab toast}                              2
# {beef fry, fish, kerala parotta}                      2
# {crab toast, kerala parotta}                          2
# {kerala parotta, appam, crab toast, mackerel fry}     2
# Name: basket_set, dtype: int64

# %%
price_calc_df_1858[price_calc_df_1858["basket_set"] == {"mackerel fry", "crab toast", "roast beef"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 6        REST1858  [(crab toast, 2), (mackerel fry, 3), (roast be...
# 361      REST1858  [(crab toast, 1), (roast beef, 2), (mackerel f...
# 442      REST1858  [(roast beef, 1), (crab toast, 3), (mackerel f...
#
#      coupon_discount  order_price  original_price  \
# 6                  0      112.010          112.01
# 361                0       85.120           85.12
# 442               10       67.662           75.18
#
#                                  basket_set
# 6    {mackerel fry, roast beef, crab toast}
# 361  {mackerel fry, roast beef, crab toast}
# 442  {mackerel fry, crab toast, roast beef}

# %%
list(price_calc_df_1858[price_calc_df_1858["basket_set"] == {"mackerel fry", "crab toast", "roast beef"}]["shopping_cart"])
# Out:
# [[('crab toast', 2), ('mackerel fry', 3), ('roast beef', 3)],
#  [('crab toast', 1), ('roast beef', 2), ('mackerel fry', 3)],
#  [('roast beef', 1), ('crab toast', 3), ('mackerel fry', 3)]]

# %%
a = np.array([[2, 3, 3], [1, 3, 2], [3, 3, 1]])
b = np.array([112.01, 85.12, 75.18])
x = np.linalg.solve(a, b)
crab_toast, mackerel_fry, roast_beef = x
rest_menu["REST1858"]["crab toast"] = crab_toast
rest_menu["REST1858"]["mackerel fry"] = mackerel_fry
rest_menu["REST1858"]["roast beef"] = roast_beef

# %%
price_calc_df_1858[price_calc_df_1858["basket_set"] == {"fish", "appam", "kerala parotta"}]
# Out:
#     restaurant_id                                 shopping_cart  \
# 270      REST1858  [(appam, 1), (kerala parotta, 1), (fish, 2)]
# 289      REST1858  [(fish, 1), (kerala parotta, 3), (appam, 2)]
# 344      REST1858  [(appam, 3), (fish, 1), (kerala parotta, 1)]
#
#      coupon_discount  order_price  original_price  \
# 270                0       67.580           67.58
# 289               10       88.389           98.21
# 344                0       90.410           90.41
#
#                         basket_set
# 270  {fish, appam, kerala parotta}
# 289  {fish, appam, kerala parotta}
# 344  {fish, appam, kerala parotta}

# %%
a = np.array([[1, 1, 2], [2, 3, 1], [3, 1, 1]])
b = np.array([67.58, 98.21, 90.41])
x = np.linalg.solve(a, b)
appam, kerala_parotta, fish = x
rest_menu["REST1858"]["appam"] = appam
rest_menu["REST1858"]["kerala parotta"] = kerala_parotta
rest_menu["REST1858"]["fish"] = fish

# %%
price_calc_df_1858[price_calc_df_1858["basket_set"] == {"mackerel fry", "beef fry"}]
# Out:
#     restaurant_id                       shopping_cart  coupon_discount  \
# 26       REST1858  [(mackerel fry, 3), (beef fry, 1)]                0
# 299      REST1858  [(beef fry, 2), (mackerel fry, 3)]               40
#
#      order_price  original_price                basket_set
# 26        47.710           47.71  {beef fry, mackerel fry}
# 299       35.058           58.43  {beef fry, mackerel fry}

# %%
beef_fry = 47.71 - (3 * rest_menu["REST1858"]["mackerel fry"])
rest_menu["REST1858"]["beef fry"] = beef_fry

# %%
rest_menu["REST1858"]
# Out:
# {'fish': 16.93,
#  'roast beef': 21.24,
#  'crab toast': 5.650000000000001,
#  'mackerel fry': 12.330000000000002,
#  'beef fry': 10.719999999999992,
#  'appam': 19.879999999999995,
#  'kerala parotta': 13.84}

# %%
price_calc_df_0936 = price_calc_df[price_calc_df["restaurant_id"] == "REST0936"].copy()

# %%
rest_menu["REST0936"]
# Out:
# {'cheesecake': 0,
#  'saffron pilaf': 0,
#  'paratha': 0,
#  'begun pora': 0,
#  'tender coconut ice cream': 0,
#  'banana chips': 0,
#  'mocha chingri': 0}

# %%
price_calc_df_0936["basket_set"].value_counts().head(40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'set'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'set'
# {cheesecake, begun pora}                                               5
# {mocha chingri, begun pora}                                            5
# {tender coconut ice cream, mocha chingri, saffron pilaf}               4
# {tender coconut ice cream, cheesecake, mocha chingri, begun pora}      4
# {tender coconut ice cream, cheesecake}                                 3
# {mocha chingri, saffron pilaf, paratha, begun pora}                    3
# {tender coconut ice cream, banana chips, paratha, begun pora}          3
# {tender coconut ice cream, mocha chingri}                              3
# {tender coconut ice cream, paratha}                                    3
# {banana chips, cheesecake, paratha, begun pora}                        3
# {tender coconut ice cream, paratha, begun pora}                        3
# {cheesecake, paratha, mocha chingri}                                   2
# {banana chips, cheesecake, saffron pilaf, paratha}                     2
# {mocha chingri, paratha}                                               2
# {banana chips, paratha}                                                2
# {banana chips, mocha chingri, cheesecake, paratha}                     2
# {saffron pilaf, begun pora}                                            2
# {tender coconut ice cream, banana chips, begun pora}                   2
# {cheesecake, saffron pilaf, paratha}                                   2
# {cheesecake, paratha}                                                  2
# {cheesecake, saffron pilaf, begun pora}                                2
# {tender coconut ice cream, banana chips, mocha chingri, paratha}       2
# {banana chips, mocha chingri, paratha, begun pora}                     2
# {saffron pilaf, paratha}                                               2
# {tender coconut ice cream, cheesecake, saffron pilaf}                  2
# {banana chips, saffron pilaf, paratha}                                 2
# {mocha chingri, saffron pilaf}                                         2
# {tender coconut ice cream, cheesecake, saffron pilaf, paratha}         2
# {banana chips, cheesecake, saffron pilaf, begun pora}                  2
# {tender coconut ice cream, mocha chingri, paratha}                     2
# {tender coconut ice cream, saffron pilaf, begun pora}                  2
# {tender coconut ice cream, cheesecake, mocha chingri}                  2
# {banana chips, begun pora}                                             2
# {tender coconut ice cream, banana chips, saffron pilaf, begun pora}    1
# {tender coconut ice cream, banana chips, mocha chingri}                1
# {banana chips, mocha chingri, saffron pilaf, paratha}                  1
# {saffron pilaf, paratha, begun pora}                                   1
# {tender coconut ice cream, cheesecake, begun pora}                     1
# {tender coconut ice cream, saffron pilaf, paratha, begun pora}         1
# {paratha, begun pora}                                                  1
# Name: basket_set, dtype: int64

# %%
price_calc_df_0936[price_calc_df_0936["basket_set"] == {"tender coconut ice cream", "mocha chingri", "cheesecake", "begun pora"}]
# Out:
#     restaurant_id                                      shopping_cart  \
# 120      REST0936  [(begun pora, 1), (cheesecake, 3), (mocha chin...
# 151      REST0936  [(tender coconut ice cream, 3), (cheesecake, 1...
# 447      REST0936  [(cheesecake, 2), (begun pora, 1), (tender coc...
# 492      REST0936  [(mocha chingri, 2), (tender coconut ice cream...
#
#      coupon_discount  order_price  original_price  \
# 120                0      121.140          121.14
# 151               45       84.887          154.34
# 447               10       97.713          108.57
# 492                0      145.170          145.17
#
#                                             basket_set
# 120  {tender coconut ice cream, cheesecake, mocha c...
# 151  {tender coconut ice cream, cheesecake, mocha c...
# 447  {tender coconut ice cream, cheesecake, mocha c...
# 492  {tender coconut ice cream, mocha chingri, chee...

# %%
list(price_calc_df_0936[price_calc_df_0936["basket_set"] == {"tender coconut ice cream", "mocha chingri", "cheesecake", "begun pora"}]["shopping_cart"])
# Out:
# [[('begun pora', 1),
#   ('cheesecake', 3),
#   ('mocha chingri', 1),
#   ('tender coconut ice cream', 2)],
#  [('tender coconut ice cream', 3),
#   ('cheesecake', 1),
#   ('mocha chingri', 3),
#   ('begun pora', 1)],
#  [('cheesecake', 2),
#   ('begun pora', 1),
#   ('tender coconut ice cream', 2),
#   ('mocha chingri', 1)],
#  [('mocha chingri', 2),
#   ('tender coconut ice cream', 1),
#   ('begun pora', 2),
#   ('cheesecake', 3)]]

# %%
a = np.array([[1, 3, 1, 2], [1, 1, 3, 3], [1, 2, 1, 2], [2, 3, 2, 1]])
b = np.array([121.14, 154.34, 108.57, 145.17])
x = np.linalg.solve(a, b)
begun_pora, cheesecake, mocha_chingri, tender_coconut_ice_cream = x
rest_menu["REST0936"]["begun pora"] = begun_pora
rest_menu["REST0936"]["cheesecake"] = cheesecake
rest_menu["REST0936"]["mocha chingri"] = mocha_chingri
rest_menu["REST0936"]["tender coconut ice cream"] = tender_coconut_ice_cream

# %%
price_calc_df_0936[price_calc_df_0936["basket_set"] == {"banana chips", "paratha"}]
# Out:
#     restaurant_id                      shopping_cart  coupon_discount  \
# 177      REST0936  [(banana chips, 2), (paratha, 3)]                0
# 423      REST0936  [(paratha, 1), (banana chips, 1)]                0
#
#      order_price  original_price               basket_set
# 177        67.28           67.28  {banana chips, paratha}
# 423        28.86           28.86  {banana chips, paratha}

# %%
a = np.array([[2,3], [1, 1]])
b = np.array([67.28, 28.86])
x = np.linalg.solve(a, b)
banana_chips, paratha = x
rest_menu["REST0936"]["banana chips"] = banana_chips
rest_menu["REST0936"]["paratha"] = paratha

# %%
price_calc_df_0936[price_calc_df_0936["basket_set"] == {"saffron pilaf", "begun pora"}]
# Out:
#     restaurant_id                          shopping_cart  coupon_discount  \
# 383      REST0936  [(begun pora, 2), (saffron pilaf, 2)]                0
# 415      REST0936  [(saffron pilaf, 3), (begun pora, 2)]                0
#
#      order_price  original_price                   basket_set
# 383        96.24           96.24  {saffron pilaf, begun pora}
# 415       119.80          119.80  {saffron pilaf, begun pora}

# %%
saffron_pilaf = (96.24 - (2 * rest_menu["REST0936"]["begun pora"])) / 2
rest_menu["REST0936"]["saffron pilaf"] = saffron_pilaf

# %%
rest_menu["REST0936"]
# Out:
# {'cheesecake': 12.570000000000007,
#  'saffron pilaf': 23.560000000000024,
#  'paratha': 9.560000000000002,
#  'begun pora': 24.559999999999974,
#  'tender coconut ice cream': 19.799999999999997,
#  'banana chips': 19.299999999999997,
#  'mocha chingri': 19.27000000000001}

# %% [markdown]
# We now have all the item prices for all the restaurants

# %%
rest_menu
# Out:
# {'REST1781': {'coffee': 22.89,
#   'beef burger': 8.870000000000001,
#   'pizza': 23.55,
#   'mango salad': 23.000000000000004,
#   'veggie pizza': 9.19,
#   'burgers': 5.679999999999993,
#   'peri peri chicken wings': 18.17,
#   'chicken burger': 11.919999999999995},
#  'REST1801': {'tandoori chicken': 18.899999999999995,
#   'hyderabadi biryani': 7.639999999999997,
#   'chicken boneless biryani': 22.700000000000003,
#   'panner tikka': 6.160000000000003,
#   'chicken guntur': 9.529999999999994,
#   'naan': 12.820000000000002,
#   'crispy chicken': 12.789999999999994},
#  'REST1450': {'puri sabzi': 19.73,
#   'poha': 8.34,
#   'rasgulla': 21.95,
#   'jalebi': 10.06999999999999,
#   'kachori': 8.16,
#   'samosa': 12.790000000000006},
#  'REST1858': {'fish': 16.93,
#   'roast beef': 21.24,
#   'crab toast': 5.650000000000001,
#   'mackerel fry': 12.330000000000002,
#   'beef fry': 10.719999999999992,
#   'appam': 19.879999999999995,
#   'kerala parotta': 13.84},
#  'REST0936': {'cheesecake': 12.570000000000007,
#   'saffron pilaf': 23.560000000000024,
#   'paratha': 9.560000000000002,
#   'begun pora': 24.559999999999974,
#   'tender coconut ice cream': 19.799999999999997,
#   'banana chips': 19.299999999999997,
#   'mocha chingri': 19.27000000000001}}

# %% [markdown]
# We will round the prices to two decimal places

# %%
# access restaurant
for key, value in rest_menu.items():
    # access menu of restaurant
    for key2, value2 in value.items():
        # round price to two decimal places
        rest_menu[key][key2] = round(value2, 2)

# %%
rest_menu
# Out:
# {'REST1781': {'coffee': 22.89,
#   'beef burger': 8.87,
#   'pizza': 23.55,
#   'mango salad': 23.0,
#   'veggie pizza': 9.19,
#   'burgers': 5.68,
#   'peri peri chicken wings': 18.17,
#   'chicken burger': 11.92},
#  'REST1801': {'tandoori chicken': 18.9,
#   'hyderabadi biryani': 7.64,
#   'chicken boneless biryani': 22.7,
#   'panner tikka': 6.16,
#   'chicken guntur': 9.53,
#   'naan': 12.82,
#   'crispy chicken': 12.79},
#  'REST1450': {'puri sabzi': 19.73,
#   'poha': 8.34,
#   'rasgulla': 21.95,
#   'jalebi': 10.07,
#   'kachori': 8.16,
#   'samosa': 12.79},
#  'REST1858': {'fish': 16.93,
#   'roast beef': 21.24,
#   'crab toast': 5.65,
#   'mackerel fry': 12.33,
#   'beef fry': 10.72,
#   'appam': 19.88,
#   'kerala parotta': 13.84},
#  'REST0936': {'cheesecake': 12.57,
#   'saffron pilaf': 23.56,
#   'paratha': 9.56,
#   'begun pora': 24.56,
#   'tender coconut ice cream': 19.8,
#   'banana chips': 19.3,
#   'mocha chingri': 19.27}}

# %% [markdown]
# We will create a function `calc_price` where the new price using the dictionary `rest_menu` will be created for each row

# %%
def calc_price(row):
    # grab the restaurant_id, shopping_cart, and coupon_discount from each row
    rest = row["restaurant_id"]
    basket = row["shopping_cart"]
    discount = row["coupon_discount"]
    total = 0
    
    for item in basket:
        food = item[0]
        quantity = item[1]
        # grab the price for the item from the relevant restaurant dictionary and multiply by the quantity
        item_total = rest_menu[rest][food] * quantity
        # update total
        total += item_total
        
    return round(total, 2)

# %%
# apply calc_price to price_calc_df
price_calc_df["new_price"] = price_calc_df.apply(calc_price, axis = 1)
price_calc_df.head()
# Out:
#   restaurant_id                                      shopping_cart  \
# 0      REST1781            [(beef burger, 3), (chicken burger, 2)]
# 1      REST1801  [(tandoori chicken, 2), (chicken guntur, 3), (...
# 2      REST1781  [(veggie pizza, 2), (chicken burger, 3), (beef...
# 3      REST1801  [(crispy chicken, 3), (naan, 1), (tandoori chi...
# 4      REST1450  [(poha, 3), (jalebi, 3), (puri sabzi, 1), (ras...
#
#    coupon_discount  order_price  original_price  \
# 0               20       40.360           50.45
# 1               10       70.839           78.71
# 2               20       64.600           80.75
# 3               10      110.853          123.17
# 4               40       58.146           96.91
#
#                                           basket_set  new_price
# 0                      {beef burger, chicken burger}      50.45
# 1   {tandoori chicken, chicken guntur, panner tikka}      78.71
# 2        {veggie pizza, beef burger, chicken burger}      80.75
# 3  {hyderabadi biryani, tandoori chicken, naan, c...     123.17
# 4               {jalebi, rasgulla, puri sabzi, poha}      96.91

# %% [markdown]
# We will verify if the process was correct by ensuring that all `new_price` are equal to `order_price`

# %%
price_calc_df[price_calc_df["original_price"] != price_calc_df["new_price"]]
# Out:
# Empty DataFrame
# Columns: [restaurant_id, shopping_cart, coupon_discount, order_price, original_price, basket_set, new_price]
# Index: []

# %% [markdown]
# We can see that the two columns are equal. We will run our prices on a copy of `outliers` to double-check. The necessary columns will be created

# %%
out = outliers.copy()
out["shopping_cart"] = out["shopping_cart"].apply(literal_eval)
out["original_price"] = round(out["order_price"] / (1 - (out["coupon_discount"] / 100)), 2)
out["new_price"] = out.apply(calc_price, axis = 1)

# %%
out[out["original_price"] != out["new_price"]]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, delivery_charges, original_price, new_price]
# Index: []

# %% [markdown]
# `original_price` is equal to `new_price` for all the rows in `outliers` as well, therefore we are confident in our item prices. We can use our `rest_menu` dictionary to check the prices in our `dirty` dataframe.
#
# #### 3.7.2 Check Prices in `dirty`
#
# First we will need to create a new `shopping_list` column that converts the string `shopping_cart` into a list as was done above

# %%
dirty["shopping_list"] = dirty["shopping_cart"].apply(literal_eval)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  \
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126
#
#                                        shopping_list
# 0  [(cheesecake, 2), (tender coconut ice cream, 1...
# 1                         [(rasgulla, 1), (poha, 2)]
# 2  [(rasgulla, 2), (poha, 2), (kachori, 1), (samo...
# 3                 [(mocha chingri, 3), (paratha, 3)]
# 4   [(tandoori chicken, 2), (hyderabadi biryani, 3)]

# %% [markdown]
# We will also create a new `original_price` column as was done in the `missing` data to obtain the prices prior to discount. This is done so that when we encounter errors in the `order_price` column, we can use `original_price` to determine if the error is actually located in the `coupon_discount` column vs the `order_price` column. This will be illustrated later on

# %%
dirty["original_price"] = round(dirty["order_price"] / (1 - (dirty["coupon_discount"] / 100)), 2)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  \
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126
#
#                                        shopping_list  original_price
# 0  [(cheesecake, 2), (tender coconut ice cream, 1...          122.08
# 1                         [(rasgulla, 1), (poha, 2)]           38.63
# 2  [(rasgulla, 2), (poha, 2), (kachori, 1), (samo...           81.53
# 3                 [(mocha chingri, 3), (paratha, 3)]           86.49
# 4   [(tandoori chicken, 2), (hyderabadi biryani, 3)]           60.72

# %% [markdown]
# Now we will apply `calc_price` to `dirty` to create the updated prices. However, we will first need to update `calc_price` to account for the newly created `shopping_list` instead of `shopping_cart`. The updated function is called `calc_price2`

# %%
def calc_price2(row):
    # grab the restaurant_id, shopping_cart, and coupon_discount from each row
    rest = row["restaurant_id"]
    basket = row["shopping_list"]
    discount = row["coupon_discount"]
    total = 0
    
    for item in basket:
        food = item[0]
        quantity = item[1]
        # grab the price for the item from the relevant restaurant dictionary and multiply by the quantity
        item_total = rest_menu[rest][food] * quantity
        # update total
        total += item_total
        
    return round(total, 2)

# %%
dirty["new_price"] = dirty.apply(calc_price2, axis = 1)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend  ...  \
# 0  2020-06-20  17:24:23             0           1  ...
# 1  2020-12-18  13:15:09             1           0  ...
# 2  2020-02-17  07:19:07             0           0  ...
# 3  2020-03-26  06:47:28             0           0  ...
# 4  2020-05-02  08:34:17             0           1  ...
#
#                                        shopping_cart coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...               0
# 1                     [('rasgulla', 1), ('poha', 2)]              45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...               0
# 3             [('mocha chingri', 3), ('paratha', 3)]              10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...               0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  \
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126
#
#                                        shopping_list original_price  new_price
# 0  [(cheesecake, 2), (tender coconut ice cream, 1...         122.08     122.08
# 1                         [(rasgulla, 1), (poha, 2)]          38.63      38.63
# 2  [(rasgulla, 2), (poha, 2), (kachori, 1), (samo...          81.53      81.53
# 3                 [(mocha chingri, 3), (paratha, 3)]          86.49      86.49
# 4   [(tandoori chicken, 2), (hyderabadi biryani, 3)]          60.72      60.72
#
# [5 rows x 21 columns]

# %% [markdown]
# Now we can locate the rows with the errors

# %%
dirty[dirty["original_price"] != dirty["new_price"]]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 39   ORD121388      REST1450   CUST06778   COUR2048    -37.807405
# 56   ORD222615      REST1781   CUST01268   COUR3713    -37.804112
# 73   ORD150215      REST1781   CUST10344   COUR1065    -37.804987
# 109  ORD212779      REST1781   CUST00763   COUR1127    -37.818114
# 184  ORD191315      REST1781   CUST10723   COUR1125    -37.813849
# 223  ORD144323      REST1781   CUST04991   COUR0813    -37.810667
# 321  ORD128037      REST0936   CUST07100   COUR1846    -37.805604
# 322  ORD102275      REST1450   CUST08860   COUR3177    -37.818585
# 340  ORD160829      REST0936   CUST12039   COUR3531    -37.801096
# 344  ORD066770      REST1858   CUST04141   COUR1554    -37.818821
# 360  ORD077179      REST1781   CUST04332   COUR1666    -37.820320
# 406  ORD142767      REST1801   CUST00300   COUR4820    -37.802366
# 492  ORD223700      REST0936   CUST11509   COUR4522    -37.803761
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 39     144.943885  2020-12-02  02:54:03             0           0  ...
# 56     144.973937  2020-04-09  06:11:52             0           0  ...
# 73     144.972398  2020-01-10  19:11:12             1           0  ...
# 109    144.961361  2020-12-23  04:17:08             0           0  ...
# 184    144.983619  2020-07-05  01:15:09             0           1  ...
# 223    144.971586  2020-06-03  04:48:47             0           0  ...
# 321    144.953620  2020-07-14  20:10:32             0           0  ...
# 322    144.967184  2020-03-03  10:09:13             0           0  ...
# 340    144.956745  2020-01-17  20:34:17             0           0  ...
# 344    144.981872  2020-07-29  17:52:05             0           0  ...
# 360    144.980883  2020-12-09  07:58:40             0           0  ...
# 406    144.962057  2020-12-23  22:36:55             0           0  ...
# 492    144.932072  2020-03-21  12:11:52             1           1  ...
#
#                                          shopping_cart coupon_discount  \
# 39   [('jalebi', 2), ('puri sabzi', 1), ('rasgulla'...              45
# 56         [('chicken burger', 1), ('beef burger', 3)]               0
# 73   [('chicken burger', 3), ('peri peri chicken wi...              20
# 109  [('peri peri chicken wings', 3), ('mango salad...               0
# 184  [('pizza', 2), ('beef burger', 2), ('chicken b...              40
# 223  [('peri peri chicken wings', 1), ('veggie pizz...               0
# 321  [('tender coconut ice cream', 3), ('mocha chin...              40
# 322                    [('jalebi', 3), ('kachori', 2)]              40
# 340  [('saffron pilaf', 3), ('mocha chingri', 2), (...              10
# 344  [('fish', 2), ('crab toast', 2), ('appam', 1),...               0
# 360                [('pizza', 2), ('veggie pizza', 3)]              20
# 406  [('hyderabadi biryani', 1), ('tandoori chicken...              45
# 492  [('begun pora', 1), ('mocha chingri', 1), ('sa...               0
#
#      order_price  shortest_distance_to_customer  travel_time_minutes  \
# 39        62.810                           1773                    9
# 56        46.380                           1727                    3
# 73       113.270                           1751                    9
# 109       75.290                            899                    2
# 184       69.084                           2093                    4
# 223       64.466                            899                    4
# 321      187.920                           2108                    5
# 322       25.592                           1347                    3
# 340       53.920                           2812                    7
# 344       58.608                            392                    1
# 360       41.069                           2054                    5
# 406       50.368                            469                    2
# 492       68.238                            985                    5
#
#      restaurant_rating  delivery_charges  \
# 39                7.71            4.0842
# 56                8.27            3.1903
# 73                8.27            5.2846
# 109               8.27            2.7703
# 184               8.27            4.1152
# 223               8.27            3.1348
# 321               9.58            3.2227
# 322               7.71            3.2111
# 340               9.58            3.1411
# 344               7.06            2.8563
# 360               8.27            3.2617
# 406               9.72            2.5752
# 492               9.58            5.4924
#
#                                          shopping_list original_price  \
# 39       [(jalebi, 2), (puri sabzi, 1), (rasgulla, 2)]         114.20
# 56             [(chicken burger, 1), (beef burger, 3)]          46.38
# 73   [(chicken burger, 3), (peri peri chicken wings...         141.59
# 109  [(peri peri chicken wings, 3), (mango salad, 2...          75.29
# 184  [(pizza, 2), (beef burger, 2), (chicken burger...         115.14
# 223  [(peri peri chicken wings, 1), (veggie pizza, ...          64.47
# 321  [(tender coconut ice cream, 3), (mocha chingri...         313.20
# 322                        [(jalebi, 3), (kachori, 2)]          42.65
# 340  [(saffron pilaf, 3), (mocha chingri, 2), (bana...          59.91
# 344  [(fish, 2), (crab toast, 2), (appam, 1), (kera...          58.61
# 360                    [(pizza, 2), (veggie pizza, 3)]          51.34
# 406   [(hyderabadi biryani, 1), (tandoori chicken, 1)]          91.58
# 492  [(begun pora, 1), (mocha chingri, 1), (saffron...          68.24
#
#      new_price
# 39       83.77
# 56       38.53
# 73      113.27
# 109     118.89
# 184      76.76
# 223      60.39
# 321     187.92
# 322      46.53
# 340     185.53
# 344     106.56
# 360      74.67
# 406      26.54
# 492     124.07
#
# [13 rows x 21 columns]

# %% [markdown]
# We can see the above rows have incorrect `original_price`, and consequently incorrect `order_price`. However, before we assume the error is due to `original_price` alone, we need to check that the correct `coupon_discount` was applied to the price. This is done by calculating the actual discount applied by using the following formula:
#
# **(1 - (order_price / new_price)) * 100**
#
# The result will be outputted to a new column `discount_applied`.
#
# If, for a given row, `coupon_discount` is not equal to `discount_applied` **and** `discount_applied` is equal to one of the allowed values of disounts [0, 10, 20, 40, 45], then `order_price` is correct and the error is in `coupon_discount`.
#
# If, however, the `discount_applied` is not equal to one of the accepted values, then the error is in fact solely due to an incorrect `order_price`.
#
# We will verify that all the value in the `coupon_discount` columns are acceptable by being one of [0, 10, 20, 40, 45]

# %%
sorted(list(dirty["coupon_discount"].unique()))
# Out:
# [0, 10, 20, 40, 45]

# %% [markdown]
# All the values in `coupon_discount` are acceptable.
#
# Two new columns will now be created:
#
# - `order_price_round`: `order_price` rounded to two decimals places instead of three. This is done to avoid discrepancies due to rounding errors
# - `discount_applied`: as explained above

# %%
dirty["order_price_round"] = round(dirty["order_price"], 2)
dirty["discount_applied"] = ((1 - (dirty["order_price_round"] / dirty["new_price"])) * 100).apply(round)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend  ... order_price  \
# 0  2020-06-20  17:24:23             0           1  ...     122.080
# 1  2020-12-18  13:15:09             1           0  ...      21.246
# 2  2020-02-17  07:19:07             0           0  ...      81.530
# 3  2020-03-26  06:47:28             0           0  ...      77.841
# 4  2020-05-02  08:34:17             0           1  ...      60.720
#
#   shortest_distance_to_customer  travel_time_minutes  restaurant_rating  \
# 0                          5413                   11               9.58
# 1                          2687                    5               7.71
# 2                          2052                   20               7.71
# 3                          2594                    6               9.58
# 4                          1235                    2               9.72
#
#    delivery_charges                                      shopping_list  \
# 0            4.7296  [(cheesecake, 2), (tender coconut ice cream, 1...
# 1            4.6335                         [(rasgulla, 1), (poha, 2)]
# 2            3.2905  [(rasgulla, 2), (poha, 2), (kachori, 1), (samo...
# 3            3.0872                 [(mocha chingri, 3), (paratha, 3)]
# 4            3.7126   [(tandoori chicken, 2), (hyderabadi biryani, 3)]
#
#    original_price  new_price order_price_round  discount_applied
# 0          122.08     122.08            122.08                 0
# 1           38.63      38.63             21.25                45
# 2           81.53      81.53             81.53                 0
# 3           86.49      86.49             77.84                10
# 4           60.72      60.72             60.72                 0
#
# [5 rows x 23 columns]

# %% [markdown]
# We will locate the rows with incorrect `coupon_discount` as described above

# %%
dirty[(dirty["coupon_discount"] != dirty["discount_applied"]) & (dirty["discount_applied"].isin(dirty["coupon_discount"].unique()))]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 73   ORD150215      REST1781   CUST10344   COUR1065    -37.804987
# 184  ORD191315      REST1781   CUST10723   COUR1125    -37.813849
# 321  ORD128037      REST0936   CUST07100   COUR1846    -37.805604
# 322  ORD102275      REST1450   CUST08860   COUR3177    -37.818585
# 344  ORD066770      REST1858   CUST04141   COUR1554    -37.818821
# 360  ORD077179      REST1781   CUST04332   COUR1666    -37.820320
# 492  ORD223700      REST0936   CUST11509   COUR4522    -37.803761
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 73     144.972398  2020-01-10  19:11:12             1           0  ...
# 184    144.983619  2020-07-05  01:15:09             0           1  ...
# 321    144.953620  2020-07-14  20:10:32             0           0  ...
# 322    144.967184  2020-03-03  10:09:13             0           0  ...
# 344    144.981872  2020-07-29  17:52:05             0           0  ...
# 360    144.980883  2020-12-09  07:58:40             0           0  ...
# 492    144.932072  2020-03-21  12:11:52             1           1  ...
#
#     order_price shortest_distance_to_customer  travel_time_minutes  \
# 73      113.270                          1751                    9
# 184      69.084                          2093                    4
# 321     187.920                          2108                    5
# 322      25.592                          1347                    3
# 344      58.608                           392                    1
# 360      41.069                          2054                    5
# 492      68.238                           985                    5
#
#      restaurant_rating  delivery_charges  \
# 73                8.27            5.2846
# 184               8.27            4.1152
# 321               9.58            3.2227
# 322               7.71            3.2111
# 344               7.06            2.8563
# 360               8.27            3.2617
# 492               9.58            5.4924
#
#                                          shopping_list  original_price  \
# 73   [(chicken burger, 3), (peri peri chicken wings...          141.59
# 184  [(pizza, 2), (beef burger, 2), (chicken burger...          115.14
# 321  [(tender coconut ice cream, 3), (mocha chingri...          313.20
# 322                        [(jalebi, 3), (kachori, 2)]           42.65
# 344  [(fish, 2), (crab toast, 2), (appam, 1), (kera...           58.61
# 360                    [(pizza, 2), (veggie pizza, 3)]           51.34
# 492  [(begun pora, 1), (mocha chingri, 1), (saffron...           68.24
#
#      new_price order_price_round  discount_applied
# 73      113.27            113.27                 0
# 184      76.76             69.08                10
# 321     187.92            187.92                 0
# 322      46.53             25.59                45
# 344     106.56             58.61                45
# 360      74.67             41.07                45
# 492     124.07             68.24                45
#
# [7 rows x 23 columns]

# %% [markdown]
# The above rows have the incorrect `coupon_discount` applied to the `original_price`, the actual discounts are presented in the `discount_applied` column, which are also of acceptable value. As such, the `coupon_discount` for these rows will be set to equal `discount_applied`.
#
# First we will pass the above filter to a mask variable

# %%
mask = (dirty["coupon_discount"] != dirty["discount_applied"]) & (dirty["discount_applied"].isin(dirty["coupon_discount"].unique()))

# %%
# set coupon_discount equal to discount_applied
dirty.loc[mask, "coupon_discount"] = dirty.loc[mask, "discount_applied"]

# %% [markdown]
# Check again

# %%
dirty[(dirty["coupon_discount"] != dirty["discount_applied"]) & (dirty["discount_applied"].isin(dirty["coupon_discount"].unique()))]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges, shopping_list, original_price, new_price, order_price_round, discount_applied]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# The `coupon_discount` column is now free of errors.
#
# To find the errors in `order_price`, a new column called `new_price_disc` will be created which is equal to `new_price` after applying `coupon_discount`. This new column will be compared to `order_price_round` to discover the errors.

# %%
dirty["new_price_disc"] = round(dirty["new_price"] * (1 - (dirty["coupon_discount"] / 100)), 2)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend  ...  \
# 0  2020-06-20  17:24:23             0           1  ...
# 1  2020-12-18  13:15:09             1           0  ...
# 2  2020-02-17  07:19:07             0           0  ...
# 3  2020-03-26  06:47:28             0           0  ...
# 4  2020-05-02  08:34:17             0           1  ...
#
#   shortest_distance_to_customer travel_time_minutes  restaurant_rating  \
# 0                          5413                  11               9.58
# 1                          2687                   5               7.71
# 2                          2052                  20               7.71
# 3                          2594                   6               9.58
# 4                          1235                   2               9.72
#
#    delivery_charges                                      shopping_list  \
# 0            4.7296  [(cheesecake, 2), (tender coconut ice cream, 1...
# 1            4.6335                         [(rasgulla, 1), (poha, 2)]
# 2            3.2905  [(rasgulla, 2), (poha, 2), (kachori, 1), (samo...
# 3            3.0872                 [(mocha chingri, 3), (paratha, 3)]
# 4            3.7126   [(tandoori chicken, 2), (hyderabadi biryani, 3)]
#
#    original_price  new_price  order_price_round discount_applied  \
# 0          122.08     122.08             122.08                0
# 1           38.63      38.63              21.25               45
# 2           81.53      81.53              81.53                0
# 3           86.49      86.49              77.84               10
# 4           60.72      60.72              60.72                0
#
#    new_price_disc
# 0          122.08
# 1           21.25
# 2           81.53
# 3           77.84
# 4           60.72
#
# [5 rows x 24 columns]

# %%
# compare absolute value of difference to two decimal places to account for rounding discrepancies
dirty[abs(dirty["order_price"] - dirty["new_price_disc"]) > 0.01]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 39   ORD121388      REST1450   CUST06778   COUR2048    -37.807405
# 56   ORD222615      REST1781   CUST01268   COUR3713    -37.804112
# 109  ORD212779      REST1781   CUST00763   COUR1127    -37.818114
# 223  ORD144323      REST1781   CUST04991   COUR0813    -37.810667
# 340  ORD160829      REST0936   CUST12039   COUR3531    -37.801096
# 406  ORD142767      REST1801   CUST00300   COUR4820    -37.802366
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 39     144.943885  2020-12-02  02:54:03             0           0  ...
# 56     144.973937  2020-04-09  06:11:52             0           0  ...
# 109    144.961361  2020-12-23  04:17:08             0           0  ...
# 223    144.971586  2020-06-03  04:48:47             0           0  ...
# 340    144.956745  2020-01-17  20:34:17             0           0  ...
# 406    144.962057  2020-12-23  22:36:55             0           0  ...
#
#     shortest_distance_to_customer travel_time_minutes  restaurant_rating  \
# 39                           1773                   9               7.71
# 56                           1727                   3               8.27
# 109                           899                   2               8.27
# 223                           899                   4               8.27
# 340                          2812                   7               9.58
# 406                           469                   2               9.72
#
#      delivery_charges                                      shopping_list  \
# 39             4.0842      [(jalebi, 2), (puri sabzi, 1), (rasgulla, 2)]
# 56             3.1903            [(chicken burger, 1), (beef burger, 3)]
# 109            2.7703  [(peri peri chicken wings, 3), (mango salad, 2...
# 223            3.1348  [(peri peri chicken wings, 1), (veggie pizza, ...
# 340            3.1411  [(saffron pilaf, 3), (mocha chingri, 2), (bana...
# 406            2.5752   [(hyderabadi biryani, 1), (tandoori chicken, 1)]
#
#      original_price  new_price  order_price_round discount_applied  \
# 39           114.20      83.77              62.81               25
# 56            46.38      38.53              46.38              -20
# 109           75.29     118.89              75.29               37
# 223           64.47      60.39              64.47               -7
# 340           59.91     185.53              53.92               71
# 406           91.58      26.54              50.37              -90
#
#      new_price_disc
# 39            46.07
# 56            38.53
# 109          118.89
# 223           60.39
# 340          166.98
# 406           14.60
#
# [6 rows x 24 columns]

# %% [markdown]
# The above rows have incorrect `order_price` and will be updated to equal the correct `new_price_disc`.
#
# Set a mask variable equal to the above filter

# %%
mask = abs(dirty["order_price"] - dirty["new_price_disc"]) > 0.01

# %%
# set order_price equal to new_price_disc
dirty.loc[mask, "order_price"] = dirty.loc[mask, "new_price_disc"]

# %% [markdown]
# Check again

# %%
dirty[abs(dirty["order_price"] - dirty["new_price_disc"]) > 0.01]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges, shopping_list, original_price, new_price, order_price_round, discount_applied, new_price_disc]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# The `order_price` column is now correct

# %% [markdown]
# Remove unneeded columns from `dirty`

# %%
dirty.drop(columns = ["shopping_list", "original_price", "new_price", "order_price_round", "discount_applied", "new_price_disc"], inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126

# %% [markdown]
# ### 3.8 shortest_distance_to_customer
#
# We will now validate the `shortest_distance_to_customer`. To accomplish this, the shortest distance from the restaurant to the customer will be calculated using the **Dijkstra algorithm**, this algorithm will be implemented using the `networkx` library.
#
# But first, let's prepare our data to contain all the required information. The information required are the nodes for both restaurants and customers.
#
# #### 3.8.1 Incorporate Restaurant and Customer Nodes
#
# For the restaurants, we can obtain the nodes using the `rest_data_match` dataframe created in **section 3.2** reproduced here

# %%
rest_data_match
# Out:
#      restaurant_id restaurant_name  \
# 936       REST0936        eatwater
# 1450      REST1450     uday sweets
# 1781      REST1781          django
# 1801      REST1801   plantain leaf
# 1858      REST1858      achayyan's
#
#                                              menu_items  \
# 936   ['banana chips', 'begun pora', 'cheesecake', '...
# 1450  ['jalebi', 'kachori', 'poha', 'puri sabzi', 'r...
# 1781  ['beef burger', 'burgers', 'chicken burger', '...
# 1801  ['chicken boneless biryani', 'chicken guntur',...
# 1858  ['appam', 'beef fry', 'crab toast', 'fish', 'k...
#
#                                            reviews_list        lat  \
# 936   ['ambience: 4/5. food: 4/5. have been looking ... -37.806573
# 1450  ['for those looking for good poori-bhaji optio... -37.818838
# 1781  ['100', 'a quaint little place just off the hu... -37.814318
# 1801  ['mind blowing quality quantity and taste of t... -37.799938
# 1858  ["achayyans was our favourite lunch place for ... -37.821556
#
#              lon  rest_nodes
# 936   144.932239  3106292227
# 1450  144.954890  6167191696
# 1781  144.965565  1327098193
# 1801  144.960628   871096404
# 1858  144.983925  4380043465

# %% [markdown]
# We will drop all the unneeded columns

# %%
rest_data_nodes = rest_data_match.drop(columns = ["restaurant_name", "menu_items", "reviews_list", "lat", "lon"])
rest_data_nodes
# Out:
#      restaurant_id  rest_nodes
# 936       REST0936  3106292227
# 1450      REST1450  6167191696
# 1781      REST1781  1327098193
# 1801      REST1801   871096404
# 1858      REST1858  4380043465

# %% [markdown]
# Now we will merge `rest_nodes` into our `dirty` data

# %%
dirty = pd.merge(dirty, rest_data_nodes, on = "restaurant_id", how = "left")
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  rest_nodes
# 0               9.58            4.7296  3106292227
# 1               7.71            4.6335  6167191696
# 2               7.71            3.2905  6167191696
# 3               9.58            3.0872  3106292227
# 4               9.72            3.7126   871096404

# %% [markdown]
# For the customers, first we need to load the `nodes` file which contains all the nodes corresponding to latitudes and longitudes

# %%
nodes_file = pd.read_csv("./supplementary_data/nodes.csv")
nodes_file.head()
# Out:
#         node        lat         lon
# 0  711327755 -37.807675  144.955873
# 1  711327756 -37.807094  144.955978
# 2  711327759 -37.807301  144.957817
# 3  711327760 -37.807885  144.957719
# 4  777781264 -37.805221  144.952173

# %% [markdown]
# Now we will only retrieve the nodes with latitudes and longitude that match the customers' latitudes and longitudes present in the `dirty` data. However, we must ensure that the decimal places for the latitudes and longitudes have the same decimal places (7) so that they can be matched

# %%
dirty["customer_lat"] = dirty["customer_lat"].round(7)
dirty["customer_lon"] = dirty["customer_lon"].round(7)
nodes_file["lat"] = nodes_file["lat"].round(7)
nodes_file["lon"] = nodes_file["lon"].round(7)

# %% [markdown]
# Retrieve the nodes with latitudes and longitudes that simultaneously exist in `dirty` `customer_lat` and `customer_lon`

# %%
nodes_match = nodes_file[(nodes_file["lat"].isin(dirty["customer_lat"])) & (nodes_file["lon"].isin(dirty["customer_lon"]))]
nodes_match.head()
# Out:
#            node        lat         lon
# 57   1132069624 -37.813462  144.944369
# 62   1132069641 -37.814078  144.944625
# 73     54552172 -37.820271  144.981849
# 92     54552193 -37.820890  144.984408
# 115  1224869049 -37.813574  144.941185

# %% [markdown]
# We can see that the number of unique nodes equals the number of unique customers

# %%
print("unique nodes:    ", len(nodes_match["node"].unique()))
print("unique customers:", len(dirty["customer_id"].unique()))
# Out:
# unique nodes:     491
# unique customers: 491

# %% [markdown]
# Now we will merge these nodes to the `dirty` dataframe

# %%
dirty = pd.merge(dirty, nodes_match, left_on = ["customer_lat", "customer_lon"], right_on = ["lat", "lon"], how = "left")
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend  ... coupon_discount  \
# 0  2020-06-20  17:24:23             0           1  ...               0
# 1  2020-12-18  13:15:09             1           0  ...              45
# 2  2020-02-17  07:19:07             0           0  ...               0
# 3  2020-03-26  06:47:28             0           0  ...              10
# 4  2020-05-02  08:34:17             0           1  ...               0
#
#   order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0     122.080                           5413                   11
# 1      21.246                           2687                    5
# 2      81.530                           2052                   20
# 3      77.841                           2594                    6
# 4      60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  rest_nodes        node        lat  \
# 0               9.58            4.7296  3106292227  5424203856 -37.822927
# 1               7.71            4.6335  6167191696    30947459 -37.802062
# 2               7.71            3.2905  6167191696  1560149467 -37.816395
# 3               9.58            3.0872  3106292227  3743608254 -37.822199
# 4               9.72            3.7126   871096404   676643772 -37.806474
#
#           lon
# 0  144.980852
# 1  144.965365
# 2  144.938170
# 3  144.947623
# 4  144.966435
#
# [5 rows x 22 columns]

# %% [markdown]
# We will drop the `lat` and `lon` columns because we no longer need them

# %%
dirty.drop(columns = ["lat", "lon"], inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  rest_nodes        node
# 0               9.58            4.7296  3106292227  5424203856
# 1               7.71            4.6335  6167191696    30947459
# 2               7.71            3.2905  6167191696  1560149467
# 3               9.58            3.0872  3106292227  3743608254
# 4               9.72            3.7126   871096404   676643772

# %% [markdown]
# We will rename the `rest_nodes` and `node` column to make them clearer regarding who they refer to

# %%
dirty.rename(columns = {"rest_nodes":"restaurant_node", "node":"customer_node"}, inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  restaurant_node  customer_node
# 0               9.58            4.7296       3106292227     5424203856
# 1               7.71            4.6335       6167191696       30947459
# 2               7.71            3.2905       6167191696     1560149467
# 3               9.58            3.0872       3106292227     3743608254
# 4               9.72            3.7126        871096404      676643772

# %% [markdown]
# Now we can compute the shortest distance for each order using the Dijkstra Algorithm

# %% [markdown]
# #### 3.8.2 Compute Shortest Distance
#
# To compute the shortest distance using the Dijkstra algorithm, we will use the `networkx` package. First we need to build the graph of nodes and edges

# %%
# create empty graph
G = nx.Graph()

# add nodes by passing in the node column from the nodes_file
G.add_nodes_from(nodes_file["node"])

# %% [markdown]
# The next step in building the graph is adding the edges. First, we need to import the edges data

# %%
edges = pd.read_csv("./supplementary_data/edges.csv", usecols = ["u", "v", "distance(m)"])
edges.head()
# Out:
#            u          v  distance(m)
# 0  711327755  711332946         58.0
# 1  711327755   55725841         15.0
# 2  711327755  711327760        165.0
# 3  711327756  703557073          4.0
# 4  711327756  711332946          8.0

# %% [markdown]
# Each row in the edges dataframe contains two nodes and the distance in metres between them. To add the edges with their respective weight of distance to the graph, the edges and the weight need to be in the correct format of
#
# `(u, v, {'weight': distance}`
#
# Therefore, we will apply a lambda function to each row in the edges dataframe that will output the required format to a new `edge` column so that it can be passed to the edges of the graph. This is done by indexing each row represented by the `x` with the name of the column required

# %%
edges["edge"] = edges.apply(lambda x: (int(x["u"]), int(x["v"]), {"weight": x["distance(m)"]}), axis = 1)
edges.head()
# Out:
#            u          v  distance(m)  \
# 0  711327755  711332946         58.0
# 1  711327755   55725841         15.0
# 2  711327755  711327760        165.0
# 3  711327756  703557073          4.0
# 4  711327756  711332946          8.0
#
#                                         edge
# 0   (711327755, 711332946, {'weight': 58.0})
# 1    (711327755, 55725841, {'weight': 15.0})
# 2  (711327755, 711327760, {'weight': 165.0})
# 3    (711327756, 703557073, {'weight': 4.0})
# 4    (711327756, 711332946, {'weight': 8.0})

# %% [markdown]
# We will now add the edges to the graph

# %%
G.add_edges_from(edges["edge"])

# %% [markdown]
# For each row in the `dirty` dataframe, we will calculate the shortest distance using the function `single_source_dijkstra` from `networkx`. For each row, the source and target nodes inputted to the function will be the `restaurant_node` and `customer_node` respectively. The calculated distance will be outputted to a new column `dijkstra_distance`.
#
# The `single_source_dijkstra` function returns a tuple where the first element is the shortest distance calculated, and the second element is a list of the edges in that shortest distance, therefore for each row, we will retrieve only the shortest distance by indexing the result of the function by [0]. The result will also be rounded to the nearest metre

# %%
dirty["dijkstra_distance"] = dirty.apply(
    lambda x: round(nx.single_source_dijkstra(G, x["restaurant_node"], x["customer_node"])[0]), axis = 1)

# %%
dirty[dirty["dijkstra_distance"] != dirty["shortest_distance_to_customer"]]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 27   ORD185868      REST1858   CUST11335   COUR2007    -37.804703
# 89   ORD337004      REST1801   CUST12101   COUR0332    -37.824404
# 221  ORD097017      REST1450   CUST11072   COUR0241    -37.806120
# 225  ORD013267      REST1801   CUST11836   COUR4270    -37.808403
# 263  ORD275776      REST1450   CUST03464   COUR0104    -37.819745
# 334  ORD080291      REST0936   CUST06936   COUR4602    -37.805872
# 341  ORD323420      REST1781   CUST03813   COUR3827    -37.802902
# 358  ORD094683      REST1801   CUST05193   COUR4456    -37.821261
# 361  ORD104816      REST1450   CUST04948   COUR2625    -37.812121
# 465  ORD290286      REST1781   CUST10415   COUR4458    -37.807924
# 473  ORD292635      REST0936   CUST07900   COUR0416    -37.816931
# 493  ORD231376      REST1858   CUST08058   COUR2587    -37.819844
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 27     144.993257  2020-12-29  06:03:57             0           0  ...
# 89     145.012952  2020-02-06  22:40:52             0           0  ...
# 221    144.948677  2020-12-24  03:37:34             0           0  ...
# 225    144.975827  2020-12-07  15:17:48             0           0  ...
# 263    144.994335  2020-12-01  11:56:02             0           0  ...
# 334    144.955761  2020-12-04  12:03:57             1           0  ...
# 341    145.009872  2020-01-14  23:52:05             0           0  ...
# 358    144.957795  2020-04-11  00:00:00             0           1  ...
# 361    144.973953  2020-10-28  04:40:52             0           0  ...
# 465    144.970436  2020-03-05  08:54:03             0           0  ...
# 473    144.988128  2020-07-23  15:09:53             0           0  ...
# 493    145.011673  2020-08-17  18:23:44             1           0  ...
#
#                                          shopping_cart coupon_discount  \
# 27                [('kerala parotta', 1), ('fish', 1)]              10
# 89   [('hyderabadi biryani', 2), ('chicken boneless...              20
# 221                  [('kachori', 1), ('rasgulla', 3)]              45
# 225  [('naan', 2), ('hyderabadi biryani', 3), ('chi...               0
# 263       [('samosa', 3), ('poha', 2), ('kachori', 1)]               0
# 334  [('tender coconut ice cream', 2), ('banana chi...              20
# 341  [('coffee', 1), ('veggie pizza', 3), ('burgers...              45
# 358  [('hyderabadi biryani', 3), ('crispy chicken',...              45
# 361  [('poha', 3), ('puri sabzi', 1), ('rasgulla', ...               0
# 465  [('burgers', 1), ('peri peri chicken wings', 1...               0
# 473  [('cheesecake', 3), ('saffron pilaf', 1), ('pa...              40
# 493  [('fish', 1), ('roast beef', 3), ('mackerel fr...               0
#
#      order_price  shortest_distance_to_customer  travel_time_minutes  \
# 27        27.693                           3000                    6
# 89        99.432                           3402                   32
# 221       40.706                           3066                    4
# 225      116.660                           2889                   10
# 263       63.210                            730                   19
# 334       93.272                           1660                   12
# 341       34.001                           2399                   25
# 358       71.962                           3990                   15
# 361      108.790                           1926                    4
# 465      111.230                           1555                    3
# 473       77.238                           2816                   29
# 493      159.160                           1165                    6
#
#      restaurant_rating  delivery_charges  restaurant_node  customer_node  \
# 27                7.06            3.5463       4380043465     3360746852
# 89                9.72            5.5427        871096404     4353912833
# 221               7.71            3.0949       6167191696     3215191996
# 225               9.72            3.4600        871096404     4283908121
# 263               7.71            4.5860       6167191696      440051924
# 334               9.58            5.2956       3106292227      777753001
# 341               8.27            5.1404       1327098193      541122845
# 358               9.72            5.0310        871096404      591342509
# 361               7.71            3.1798       6167191696      588197213
# 465               8.27            3.0851       1327098193     2948774579
# 473               9.58            5.7195       3106292227     1449308608
# 493               7.06            5.0173       4380043465     1462398739
#
#      dijkstra_distance
# 27                2388
# 89                6473
# 221               1785
# 225               2094
# 263               3876
# 334               2303
# 341               4996
# 358               2925
# 361               1956
# 465               1344
# 473               5776
# 493               2763
#
# [12 rows x 21 columns]

# %% [markdown]
# The above rows have incorrect `shortest_distance_to_customer` values.

# %% [markdown]
# Since only 12 rows from 500 are incorrect, we can be confident that our method is correct as the algorithm correctly calculated the great majority of rows at 488 rows.
#
# We will now set the incorrect values of `shortest_distance_to_customer` equal to the correct values in `dijkstra_distance`.
#
# We will first set a mask variable equal to the filter above

# %%
mask = dirty["dijkstra_distance"] != dirty["shortest_distance_to_customer"]

# %%
dirty.loc[mask, "shortest_distance_to_customer"] = dirty.loc[mask, "dijkstra_distance"]

# %%
dirty[dirty["dijkstra_distance"] != dirty["shortest_distance_to_customer"]]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges, restaurant_node, customer_node, dijkstra_distance]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# The values under `shortest_distance_to_customer` are now correct.
#
# We will now remove the columns no longer needed

# %%
dirty.drop(columns = ["restaurant_node", "customer_node", "dijkstra_distance"], inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                   20
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126

# %% [markdown]
# ### 3.9 travel_time_minutes and carrier_vehicle
#
# `travel_time_minutes` depends on both `shortest_distance_to_customer` and the speed according to `carrier_vehicle`. The following speeds apply according to `carrier_vehicle`:
#
# - Motorbike: 30KM/hour
# - Bike: 12KM/hour
# - Car: 25KM/hour
#
# The formula to calculate `travel_time_minutes` is `shortest_distance_to_customer` divided by speed according to `carrier_vehicle`
#
# However, it is important to note and adjust for 2 things:
#
# 1. The speed is in KM but `shortest_distance_to_customer` is in metres, therefore `shortest_distance_to_customer` needs to be converted to KM by dividing by 1,000
# 2. The speed is per hour but `travel_time_minutes` is in minutes, therefore a new speed figure per minute will be calculated by dividing by 60
#
# First, we will check the values in `carrier_vehicle` are one of **Motorbike, Bike, Car**

# %%
list(dirty["carrier_vehicle"].unique())
# Out:
# ['Motorbike', 'Car', 'Bike', 'motorbike', 'car', 'bike']

# %% [markdown]
# Some rows contain the vehicle type in lowercase, these will now be capitalised using `str.capitalize`

# %%
dirty["carrier_vehicle"] = dirty["carrier_vehicle"].str.capitalize()

# %% [markdown]
# Let's check that all the values in `carrier_vehicle` are now capitalized

# %%
list(dirty["carrier_vehicle"].unique())
# Out:
# ['Motorbike', 'Car', 'Bike']

# %% [markdown]
# A dictionary called `vehicle_speed` will be created that holds each vehicle and it's corresponding speed per minute

# %%
# divide speed by 60 to convert to per minute figure
vehicle_speeds = {"Motorbike": (30/60), "Bike": (12/60), "Car": (25/60)}

# %% [markdown]
# A new column called `new_travel_time` will be created which will hold the output of a lambda function where for each row, the time to the nearest minute according to the vehicle used will be calculated by dividing the `shortest_distance_to_customer` by the speed according to the `carrier_vehicle` retrieved from the `vehicle_speeds` dictionary. We divide `shortest_distance_to_customer` by 1,000 to convert to metres

# %%
dirty["new_travel_time"] = dirty.apply(lambda x: round((x["shortest_distance_to_customer"] / 1000) / 
                                                       vehicle_speeds[x["carrier_vehicle"]]), axis = 1)

# %% [markdown]
# We will extract the incorrect rows by comparing `travel_time_minutes` to `new_travel_time`

# %%
dirty[dirty["travel_time_minutes"] != dirty["new_travel_time"]]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 2    ORD211273      REST1450   CUST08503   COUR0136    -37.816395
# 23   ORD139394      REST0936   CUST04558   COUR4054    -37.814471
# 30   ORD326069      REST1781   CUST07017   COUR2086    -37.805540
# 60   ORD300682      REST0936   CUST11931   COUR4318    -37.816307
# 81   ORD121440      REST1450   CUST01018   COUR2236    -37.802403
# 90   ORD232548      REST1450   CUST04363   COUR3616    -37.823007
# 91   ORD159042      REST1781   CUST03231   COUR3871    -37.815584
# 122  ORD325852      REST0936   CUST07266   COUR4719    -37.820952
# 146  ORD181282      REST0936   CUST01775   COUR3489    -37.799662
# 267  ORD215378      REST1801   CUST01697   COUR4406    -37.823167
# 280  ORD328730      REST1450   CUST04807   COUR2661    -37.804305
# 352  ORD306718      REST1801   CUST11796   COUR2254    -37.814435
# 457  ORD312397      REST0936   CUST06732   COUR2273    -37.807883
# 469  ORD128129      REST1450   CUST04505   COUR1347    -37.826562
# 487  ORD078550      REST0936   CUST07450   COUR3170    -37.819847
# 490  ORD346571      REST1858   CUST07921   COUR3003    -37.815366
# 491  ORD134543      REST1781   CUST09779   COUR0634    -37.812111
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 2      144.938170  2020-02-17  07:19:07             0           0
# 23     144.949647  2020-04-18  20:26:22             0           1
# 30     144.955269  2020-02-15  21:05:56             0           1
# 60     145.013504  2020-01-06  03:37:34             0           0
# 81     144.926907  2020-01-30  05:24:23             0           0
# 90     144.987646  2020-05-12  18:00:00             1           0
# 91     144.945277  2020-08-19  20:58:01             0           0
# 122    144.948091  2020-04-15  17:32:18             0           0
# 146    144.962243  2020-12-28  20:06:35             0           0
# 267    145.004493  2020-07-21  14:26:22             0           0
# 280    144.929010  2020-09-02  16:05:16             0           0
# 352    144.942907  2020-11-25  22:52:44             0           0
# 457    144.973187  2020-10-28  11:36:15             0           0
# 469    144.974312  2020-10-29  22:36:55             0           0
# 487    144.967017  2020-02-02  18:35:36             1           1
# 490    144.974639  2020-04-05  20:34:17             0           1
# 491    144.988688  2020-05-07  16:01:19             0           0
#
#     carrier_vehicle                                      shopping_cart  \
# 2         Motorbike  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...
# 23        Motorbike  [('begun pora', 2), ('saffron pilaf', 3), ('te...
# 30             Bike  [('pizza', 1), ('coffee', 1), ('veggie pizza',...
# 60              Car  [('mocha chingri', 2), ('paratha', 1), ('chees...
# 81             Bike  [('jalebi', 3), ('puri sabzi', 3), ('rasgulla'...
# 90             Bike  [('jalebi', 1), ('poha', 2), ('puri sabzi', 1)...
# 91             Bike  [('coffee', 3), ('mango salad', 2), ('veggie p...
# 122       Motorbike  [('cheesecake', 3), ('saffron pilaf', 3), ('ba...
# 146             Car  [('cheesecake', 3), ('paratha', 3), ('tender c...
# 267             Car       [('panner tikka', 2), ('crispy chicken', 2)]
# 280             Car                   [('jalebi', 2), ('rasgulla', 1)]
# 352             Car  [('naan', 1), ('hyderabadi biryani', 1), ('tan...
# 457       Motorbike        [('saffron pilaf', 3), ('banana chips', 3)]
# 469            Bike                       [('poha', 1), ('jalebi', 2)]
# 487            Bike  [('mocha chingri', 3), ('begun pora', 3), ('ba...
# 490       Motorbike  [('beef fry', 3), ('mackerel fry', 2), ('appam...
# 491       Motorbike               [('coffee', 3), ('veggie pizza', 2)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 2                  0       81.530                           2052
# 23                45       87.670                           1909
# 30                40       44.406                           1660
# 60                20       68.184                           7933
# 81                 0      128.030                           3307
# 90                 0       68.430                           3319
# 91                 0      159.620                           2155
# 122                0      166.290                           2513
# 146               10       77.571                           3393
# 267               20       30.320                           5603
# 280                0       42.090                           3015
# 352               10       69.444                           2839
# 457               45       70.719                           3872
# 469                0       28.480                           2459
# 487                0      170.090                           4069
# 490                0      150.320                           1280
# 491               10       78.345                           2545
#
#      travel_time_minutes  restaurant_rating  delivery_charges  new_travel_time
# 2                     20               7.71            3.2905                4
# 23                     7               9.58            3.6509                4
# 30                    36               8.27            4.3912                8
# 60                    16               9.58            4.1269               19
# 81                     5               7.71            4.5904               17
# 90                     7               7.71            4.9780               17
# 91                     6               8.27            3.6893               11
# 122                   34               9.58            3.1727                5
# 146                    7               9.58            3.2963                8
# 267                    2               9.72            3.7696               13
# 280                    6               7.71            3.5066                7
# 352                    1               9.72            3.2403                7
# 457                   12               9.58            3.4093                8
# 469                    6               7.71            3.6223               12
# 487                   16               9.58            6.8449               20
# 490                    6               7.06            4.3336                3
# 491                    6               8.27            3.2892                5

# %% [markdown]
# The above rows have differing `travel_time_minutes` and `new_travel_time`. However, before assuming the error is in `travel_time_minutes` itself, we must first check if the error is in fact in `carrier_vehicle`, this will be done by generating the time figure if the other vehicles were used other than the one specified in the row. If we find that the given `travel_time_minutes` equals the travel time if another vehicle is used, then this indicates that the error is in the `carrier_vehicle` column rather than the `travel_time_minutes` column.

# %% [markdown]
# We will create three new columns which calculates the time according to the different vehicle speeds:
#
# - `motor_time`: time calculated by using motorbike speed
# - `bike_time`: time calculated by using bike speed
# - `car_time`: time calculated by using car speed

# %%
dirty["motor_time"] = ((dirty["shortest_distance_to_customer"]/1000) / vehicle_speeds["Motorbike"]).apply(round)
dirty["bike_time"] = ((dirty["shortest_distance_to_customer"]/1000) / vehicle_speeds["Bike"]).apply(round)
dirty["car_time"] = ((dirty["shortest_distance_to_customer"]/1000) / vehicle_speeds["Car"]).apply(round)

# %% [markdown]
# Now we will locate the rows where `travel_time_minutes` does not equal `new_travel_time` **AND** `travel_time_minutes` equals one of the other times if another vehicle was used

# %%
dirty[(dirty["travel_time_minutes"] != dirty["new_travel_time"]) &
      ((dirty["travel_time_minutes"] == dirty["motor_time"]) | (dirty["travel_time_minutes"] == dirty["bike_time"]) | (dirty["travel_time_minutes"] == dirty["car_time"]))]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 60   ORD300682      REST0936   CUST11931   COUR4318    -37.816307
# 90   ORD232548      REST1450   CUST04363   COUR3616    -37.823007
# 146  ORD181282      REST0936   CUST01775   COUR3489    -37.799662
# 280  ORD328730      REST1450   CUST04807   COUR2661    -37.804305
# 469  ORD128129      REST1450   CUST04505   COUR1347    -37.826562
# 490  ORD346571      REST1858   CUST07921   COUR3003    -37.815366
# 491  ORD134543      REST1781   CUST09779   COUR0634    -37.812111
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 60     145.013504  2020-01-06  03:37:34             0           0  ...
# 90     144.987646  2020-05-12  18:00:00             1           0  ...
# 146    144.962243  2020-12-28  20:06:35             0           0  ...
# 280    144.929010  2020-09-02  16:05:16             0           0  ...
# 469    144.974312  2020-10-29  22:36:55             0           0  ...
# 490    144.974639  2020-04-05  20:34:17             0           1  ...
# 491    144.988688  2020-05-07  16:01:19             0           0  ...
#
#     coupon_discount order_price  shortest_distance_to_customer  \
# 60               20      68.184                           7933
# 90                0      68.430                           3319
# 146              10      77.571                           3393
# 280               0      42.090                           3015
# 469               0      28.480                           2459
# 490               0     150.320                           1280
# 491              10      78.345                           2545
#
#      travel_time_minutes  restaurant_rating  delivery_charges  \
# 60                    16               9.58            4.1269
# 90                     7               7.71            4.9780
# 146                    7               9.58            3.2963
# 280                    6               7.71            3.5066
# 469                    6               7.71            3.6223
# 490                    6               7.06            4.3336
# 491                    6               8.27            3.2892
#
#      new_travel_time  motor_time  bike_time  car_time
# 60                19          16         40        19
# 90                17           7         17         8
# 146                8           7         17         8
# 280                7           6         15         7
# 469               12           5         12         6
# 490                3           3          6         3
# 491                5           5         13         6
#
# [7 rows x 22 columns]

# %% [markdown]
# We can see for the above rows, `travel_time_minutes` does not equal `new_travel_time` but it does equal one of the other times if another vehicle was used. We will update the `carrier_vehicle` for those rows by creating an `update_vehicle` function which will compare `travel_time_minutes` to the different vehicles times, if the two times match, then `carrier_vehicle` will be updated to the vehicle which produced that time

# %%
def update_vehicle(row):
    # obtain necessary values
    original_time = row["travel_time_minutes"]
    motor_time = row["motor_time"]
    bike_time = row["bike_time"]
    car_time = row["car_time"]
    
    # update carrier_vehicle according to time matched
    if original_time == motor_time:
        return "Motorbike"
        
    elif original_time == bike_time:
        return "Bike"
        
    else:
        return "Car"

# %% [markdown]
# Pass the above filter into a mask variable

# %%
mask = (dirty["travel_time_minutes"] != dirty["new_travel_time"]) & ((dirty["travel_time_minutes"] == dirty["motor_time"]) | (dirty["travel_time_minutes"] == dirty["bike_time"]) | (dirty["travel_time_minutes"] == dirty["car_time"]))

# %% [markdown]
# Alter the values of `carrier_vehicle` in the rows above by applying `update_vehicle` function

# %%
dirty.loc[mask, "carrier_vehicle"] = dirty.loc[mask].apply(update_vehicle, axis = 1)

# %% [markdown]
# We will recalculate `new_travel_time` with the updated `carrier_vehicle` values

# %%
dirty["new_travel_time"] = dirty.apply(lambda x: round((x["shortest_distance_to_customer"] / 1000) / 
                                                       vehicle_speeds[x["carrier_vehicle"]]), axis = 1)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend  ... coupon_discount  \
# 0  2020-06-20  17:24:23             0           1  ...               0
# 1  2020-12-18  13:15:09             1           0  ...              45
# 2  2020-02-17  07:19:07             0           0  ...               0
# 3  2020-03-26  06:47:28             0           0  ...              10
# 4  2020-05-02  08:34:17             0           1  ...               0
#
#   order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0     122.080                           5413                   11
# 1      21.246                           2687                    5
# 2      81.530                           2052                   20
# 3      77.841                           2594                    6
# 4      60.720                           1235                    2
#
#    restaurant_rating  delivery_charges  new_travel_time  motor_time  \
# 0               9.58            4.7296               11          11
# 1               7.71            4.6335                5           5
# 2               7.71            3.2905                4           4
# 3               9.58            3.0872                6           5
# 4               9.72            3.7126                2           2
#
#    bike_time  car_time
# 0         27        13
# 1         13         6
# 2         10         5
# 3         13         6
# 4          6         3
#
# [5 rows x 22 columns]

# %% [markdown]
# Check that error is not due to incorrect `carrier_vehicle`

# %%
dirty[(dirty["travel_time_minutes"] != dirty["new_travel_time"]) &
      ((dirty["travel_time_minutes"] == dirty["motor_time"]) | (dirty["travel_time_minutes"] == dirty["bike_time"]) | (dirty["travel_time_minutes"] == dirty["car_time"]))]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges, new_travel_time, motor_time, bike_time, car_time]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# The remaining errors are solely due to incorrect `travel_time_minutes`. We will extract the incorrect rows by comparing `travel_time_minutes` to `new_travel_time` again

# %%
dirty[dirty["travel_time_minutes"] != dirty["new_travel_time"]]
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 2    ORD211273      REST1450   CUST08503   COUR0136    -37.816395
# 23   ORD139394      REST0936   CUST04558   COUR4054    -37.814471
# 30   ORD326069      REST1781   CUST07017   COUR2086    -37.805540
# 81   ORD121440      REST1450   CUST01018   COUR2236    -37.802403
# 91   ORD159042      REST1781   CUST03231   COUR3871    -37.815584
# 122  ORD325852      REST0936   CUST07266   COUR4719    -37.820952
# 267  ORD215378      REST1801   CUST01697   COUR4406    -37.823167
# 352  ORD306718      REST1801   CUST11796   COUR2254    -37.814435
# 457  ORD312397      REST0936   CUST06732   COUR2273    -37.807883
# 487  ORD078550      REST0936   CUST07450   COUR3170    -37.819847
#
#      customer_lon        date      time  is_peak_time  is_weekend  ...  \
# 2      144.938170  2020-02-17  07:19:07             0           0  ...
# 23     144.949647  2020-04-18  20:26:22             0           1  ...
# 30     144.955269  2020-02-15  21:05:56             0           1  ...
# 81     144.926907  2020-01-30  05:24:23             0           0  ...
# 91     144.945277  2020-08-19  20:58:01             0           0  ...
# 122    144.948091  2020-04-15  17:32:18             0           0  ...
# 267    145.004493  2020-07-21  14:26:22             0           0  ...
# 352    144.942907  2020-11-25  22:52:44             0           0  ...
# 457    144.973187  2020-10-28  11:36:15             0           0  ...
# 487    144.967017  2020-02-02  18:35:36             1           1  ...
#
#     coupon_discount order_price  shortest_distance_to_customer  \
# 2                 0      81.530                           2052
# 23               45      87.670                           1909
# 30               40      44.406                           1660
# 81                0     128.030                           3307
# 91                0     159.620                           2155
# 122               0     166.290                           2513
# 267              20      30.320                           5603
# 352              10      69.444                           2839
# 457              45      70.719                           3872
# 487               0     170.090                           4069
#
#      travel_time_minutes  restaurant_rating  delivery_charges  \
# 2                     20               7.71            3.2905
# 23                     7               9.58            3.6509
# 30                    36               8.27            4.3912
# 81                     5               7.71            4.5904
# 91                     6               8.27            3.6893
# 122                   34               9.58            3.1727
# 267                    2               9.72            3.7696
# 352                    1               9.72            3.2403
# 457                   12               9.58            3.4093
# 487                   16               9.58            6.8449
#
#      new_travel_time  motor_time  bike_time  car_time
# 2                  4           4         10         5
# 23                 4           4         10         5
# 30                 8           3          8         4
# 81                17           7         17         8
# 91                11           4         11         5
# 122                5           5         13         6
# 267               13          11         28        13
# 352                7           6         14         7
# 457                8           8         19         9
# 487               20           8         20        10
#
# [10 rows x 22 columns]

# %% [markdown]
# We will now set the incorrect values of `travel_time_minutes` equal to the correct values in `new_travel_time`.
#
# We will first set a mask variable equal to the filter above

# %%
mask = dirty["travel_time_minutes"] != dirty["new_travel_time"]

# %%
dirty.loc[mask, "travel_time_minutes"] = dirty.loc[mask, "new_travel_time"]

# %%
dirty[dirty["travel_time_minutes"] != dirty["new_travel_time"]]
# Out:
# Empty DataFrame
# Columns: [order_id, restaurant_id, customer_id, carrier_id, customer_lat, customer_lon, date, time, is_peak_time, is_weekend, carrier_vehicle, shopping_cart, coupon_discount, order_price, shortest_distance_to_customer, travel_time_minutes, restaurant_rating, delivery_charges, new_travel_time, motor_time, bike_time, car_time]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# The values under `travel_time_minutes` are now correct.
#
# Since only 17 rows from 500 were changed, we can be confident that our method is correct as the function correctly calculated the greaty majority of rows at 483 rows.
#
# We will now remove the additional columns created as they are no longer needed

# %%
dirty.drop(columns = ["new_travel_time", "motor_time", "bike_time", "car_time"], inplace = True)
dirty.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD057034      REST0936   CUST13295   COUR1776    -37.822927    144.980852
# 1  ORD079938      REST1450   CUST00146   COUR0059    -37.802062    144.965365
# 2  ORD211273      REST1450   CUST08503   COUR0136    -37.816395    144.938170
# 3  ORD009241      REST0936   CUST11478   COUR0989    -37.822199    144.947623
# 4  ORD340665      REST1801   CUST05997   COUR0969    -37.806474    144.966435
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-06-20  17:24:23             0           1       Motorbike
# 1  2020-12-18  13:15:09             1           0       Motorbike
# 2  2020-02-17  07:19:07             0           0       Motorbike
# 3  2020-03-26  06:47:28             0           0             Car
# 4  2020-05-02  08:34:17             0           1       Motorbike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('cheesecake', 2), ('tender coconut ice cream...                0
# 1                     [('rasgulla', 1), ('poha', 2)]               45
# 2  [('rasgulla', 2), ('poha', 2), ('kachori', 1),...                0
# 3             [('mocha chingri', 3), ('paratha', 3)]               10
# 4  [('tandoori chicken', 2), ('hyderabadi biryani...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      122.080                           5413                   11
# 1       21.246                           2687                    5
# 2       81.530                           2052                    4
# 3       77.841                           2594                    6
# 4       60.720                           1235                    2
#
#    restaurant_rating  delivery_charges
# 0               9.58            4.7296
# 1               7.71            4.6335
# 2               7.71            3.2905
# 3               9.58            3.0872
# 4               9.72            3.7126

# %% [markdown]
# All the errors in the `dirty` file are now fixed

# %%
# save updated dirty csv
#dirty.to_csv("dirty_solution.csv", index = False)

# %% [markdown]
# ## 4. Missing Data
#
# The second part of this report examines the `missing` file where some columns contain missing values, and then imputing those missing values
#
# ### 4.1 Data Exploration
#
# A preliminary exploration will be performed.

# %%
missing.shape
# Out:
# (500, 18)

# %% [markdown]
# The data consists of 500 observations of 18 columns. Let's take a look at the five first and last rows of the data

# %%
missing
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 0    ORD105989      REST1781   CUST11240   COUR4882    -37.799476
# 1    ORD322559      REST1801   CUST07028   COUR4957    -37.803884
# 2    ORD049292      REST1781   CUST09653   COUR0307    -37.801484
# 3    ORD155078      REST1801   CUST13998   COUR0281    -37.810416
# 4    ORD276190      REST1450   CUST05808   COUR0507    -37.814478
# ..         ...           ...         ...        ...           ...
# 495  ORD319359      REST0936   CUST07398   COUR0126    -37.822728
# 496  ORD114588      REST1781   CUST05069   COUR2197    -37.819881
# 497  ORD152374      REST1858   CUST04773   COUR1652    -37.805195
# 498  ORD011152      REST1801   CUST09387   COUR0053    -37.809257
# 499  ORD236119      REST0936   CUST10930   COUR0513    -37.803565
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 0      144.936815  2020-05-24  14:42:11             0           1
# 1      144.957440  2020-03-07  12:19:46             1           1
# 2      145.004298  2020-11-16  12:47:28             1           0
# 3      144.961486  2020-12-25  02:42:11             0           0
# 4      144.978845  2020-07-21  07:15:09             0           0
# ..            ...         ...       ...           ...         ...
# 495    144.967512  2020-08-04  17:00:39             0           0
# 496    144.961283  2020-04-05  16:32:58             0           1
# 497    144.933184  2020-05-13  00:27:41             0           0
# 498    144.960791  2020-08-18  15:49:27             0           0
# 499    144.967203  2020-02-04  01:54:43             0           0
#
#     carrier_vehicle                                      shopping_cart  \
# 0         Motorbike        [('beef burger', 3), ('chicken burger', 2)]
# 1               Car  [('tandoori chicken', 2), ('chicken guntur', 3...
# 2              Bike  [('veggie pizza', 2), ('chicken burger', 3), (...
# 3              Bike  [('crispy chicken', 3), ('naan', 1), ('tandoor...
# 4               Car  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...
# ..              ...                                                ...
# 495            Bike  [('paratha', 1), ('tender coconut ice cream', 2)]
# 496            Bike  [('mango salad', 1), ('peri peri chicken wings...
# 497       Motorbike  [('beef fry', 2), ('kerala parotta', 2), ('mac...
# 498             Car  [('chicken guntur', 3), ('crispy chicken', 1),...
# 499       Motorbike  [('mocha chingri', 3), ('begun pora', 3), ('ba...
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 0                 20       40.360                         3585.0
# 1                 10       70.839                          837.0
# 2                 20       64.600                         4699.0
# 3                 10      110.853                            NaN
# 4                 40       58.146                            NaN
# ..               ...          ...                            ...
# 495                0       49.160                         4252.0
# 496               40       24.702                            NaN
# 497               10       70.542                            NaN
# 498               10       92.484                         1237.0
# 499               40      113.526                            NaN
#
#      travel_time_minutes  restaurant_rating  delivery_charges
# 0                      7                NaN            4.3510
# 1                      2                NaN            5.1515
# 2                     23                NaN            6.5655
# 3                      7                NaN               NaN
# 4                      6                NaN               NaN
# ..                   ...                ...               ...
# 495                   21                NaN            5.0617
# 496                    6                NaN               NaN
# 497                   11                NaN               NaN
# 498                    3                NaN            3.1698
# 499                    7                NaN               NaN
#
# [500 rows x 18 columns]

# %% [markdown]
# Let's examine the types of variables in our data

# %%
missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       500 non-null    object
#  1   restaurant_id                  500 non-null    object
#  2   customer_id                    500 non-null    object
#  3   carrier_id                     500 non-null    object
#  4   customer_lat                   500 non-null    float64
#  5   customer_lon                   500 non-null    float64
#  6   date                           500 non-null    object
#  7   time                           500 non-null    object
#  8   is_peak_time                   500 non-null    int64
#  9   is_weekend                     500 non-null    int64
#  10  carrier_vehicle                500 non-null    object
#  11  shopping_cart                  500 non-null    object
#  12  coupon_discount                500 non-null    int64
#  13  order_price                    500 non-null    float64
#  14  shortest_distance_to_customer  350 non-null    float64
#  15  travel_time_minutes            500 non-null    int64
#  16  restaurant_rating              0 non-null      float64
#  17  delivery_charges               350 non-null    float64
# dtypes: float64(6), int64(4), object(8)
# memory usage: 70.4+ KB

# %% [markdown]
# Let's discover where the missing values are

# %%
missing.isnull().sum()
# Out:
# order_id                           0
# restaurant_id                      0
# customer_id                        0
# carrier_id                         0
# customer_lat                       0
# customer_lon                       0
# date                               0
# time                               0
# is_peak_time                       0
# is_weekend                         0
# carrier_vehicle                    0
# shopping_cart                      0
# coupon_discount                    0
# order_price                        0
# shortest_distance_to_customer    150
# travel_time_minutes                0
# restaurant_rating                500
# delivery_charges                 150
# dtype: int64

# %% [markdown]
# We can see that `shortest_distance_to_customer` and `delivery_charges` are both missing in 150 observations, while `restaurant_rating` is missing totally. The missing values will be imputed for each of these variables

# %% [markdown]
# ### 4.2 shortest_distance_to_customer
#
# `shortest_distance_to_customer` will be calculated in a similar fashion to how it was calculated in section **3.8**.
#
# First we will merge the restaurant and customer nodes to the `missing` dataframe. For the restaurants, will use `rest_data_nodes`, which was derived using the `dirty` dataframe, from **3.8.1** reproduced here

# %%
rest_data_nodes
# Out:
#      restaurant_id  rest_nodes
# 936       REST0936  3106292227
# 1450      REST1450  6167191696
# 1781      REST1781  1327098193
# 1801      REST1801   871096404
# 1858      REST1858  4380043465

# %% [markdown]
# We will merge `rest_nodes` into our `missing` data

# %%
missing = pd.merge(missing, rest_data_nodes, on = "restaurant_id", how = "left")
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803884    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                            NaN                    7
# 4       58.146                            NaN                    6
#
#    restaurant_rating  delivery_charges  rest_nodes
# 0                NaN            4.3510  1327098193
# 1                NaN            5.1515   871096404
# 2                NaN            6.5655  1327098193
# 3                NaN               NaN   871096404
# 4                NaN               NaN  6167191696

# %% [markdown]
# For the customers, we will use the `nodes_file` created in **3.8.1** reproduced here

# %%
nodes_file.head()
# Out:
#         node        lat         lon
# 0  711327755 -37.807675  144.955873
# 1  711327756 -37.807094  144.955978
# 2  711327759 -37.807301  144.957817
# 3  711327760 -37.807885  144.957719
# 4  777781264 -37.805221  144.952173

# %% [markdown]
# Now we will only retrieve the nodes with latitudes and longitude that match the customers' latitudes and longitudes present in the `missing` data. However, we must ensure that the decimal places for the latitudes and longitudes have the same decimal places (7) so that they can be matched

# %%
missing["customer_lat"] = missing["customer_lat"].round(7)
missing["customer_lon"] = missing["customer_lon"].round(7)

# %% [markdown]
# Retrive the nodes with latitudes and longitudes that simultaneously exist in `missing` `customer_lat` and `customer_lon`

# %%
nodes_match_missing = nodes_file[(nodes_file["lat"].isin(missing["customer_lat"])) & (nodes_file["lon"].isin(missing["customer_lon"]))]
nodes_match_missing.head()
# Out:
#            node        lat         lon
# 40   3276407462 -37.818604  144.947850
# 90     54552191 -37.820687  144.984726
# 112  1224869047 -37.813922  144.940449
# 192   560989610 -37.821023  144.947451
# 226  1224869677 -37.811827  144.940588

# %% [markdown]
# We can see that the number of unique nodes equal the number of unique customers

# %%
print("unique nodes    :", len(nodes_match_missing["node"].unique()))
print("unique customers:", len(missing["customer_id"].unique()))
# Out:
# unique nodes    : 496
# unique customers: 496

# %% [markdown]
# Now we will merge these nodes to the `missing` dataframe

# %%
missing = pd.merge(missing, nodes_match_missing, left_on = ["customer_lat", "customer_lon"], right_on = ["lat", "lon"], how = "left")
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend  ... coupon_discount  \
# 0  2020-05-24  14:42:11             0           1  ...              20
# 1  2020-03-07  12:19:46             1           1  ...              10
# 2  2020-11-16  12:47:28             1           0  ...              20
# 3  2020-12-25  02:42:11             0           0  ...              10
# 4  2020-07-21  07:15:09             0           0  ...              40
#
#   order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0      40.360                         3585.0                    7
# 1      70.839                          837.0                    2
# 2      64.600                         4699.0                   23
# 3     110.853                            NaN                    7
# 4      58.146                            NaN                    6
#
#    restaurant_rating  delivery_charges  rest_nodes        node        lat  \
# 0                NaN            4.3510  1327098193  3260985583 -37.799476
# 1                NaN            5.1515   871096404   777826283 -37.803883
# 2                NaN            6.5655  1327098193  2288769482 -37.801484
# 3                NaN               NaN   871096404  6167289287 -37.810416
# 4                NaN               NaN  6167191696   650269226 -37.814478
#
#           lon
# 0  144.936815
# 1  144.957440
# 2  145.004298
# 3  144.961486
# 4  144.978845
#
# [5 rows x 22 columns]

# %% [markdown]
# We will drop the `lat` and `lon` columns because we no longer need them

# %%
missing.drop(columns = ["lat", "lon"], inplace = True)
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                            NaN                    7
# 4       58.146                            NaN                    6
#
#    restaurant_rating  delivery_charges  rest_nodes        node
# 0                NaN            4.3510  1327098193  3260985583
# 1                NaN            5.1515   871096404   777826283
# 2                NaN            6.5655  1327098193  2288769482
# 3                NaN               NaN   871096404  6167289287
# 4                NaN               NaN  6167191696   650269226

# %% [markdown]
# We will rename the `rest_nodes` and `node` column to make them clearer regarding who they refer to

# %%
missing.rename(columns = {"rest_nodes":"restaurant_node", "node":"customer_node"}, inplace = True)
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                            NaN                    7
# 4       58.146                            NaN                    6
#
#    restaurant_rating  delivery_charges  restaurant_node  customer_node
# 0                NaN            4.3510       1327098193     3260985583
# 1                NaN            5.1515        871096404      777826283
# 2                NaN            6.5655       1327098193     2288769482
# 3                NaN               NaN        871096404     6167289287
# 4                NaN               NaN       6167191696      650269226

# %% [markdown]
# Now we will calculate the shortest distance for the missing values using `nx.single_source_dijkstra` from the `networkx` package as in section **3.8.2**

# %%
missing.loc[missing["shortest_distance_to_customer"].isnull(), "shortest_distance_to_customer"] = missing[missing["shortest_distance_to_customer"].isnull()].apply(
    lambda x: round(nx.single_source_dijkstra(G, x["restaurant_node"], x["customer_node"])[0]), axis = 1)

# %%
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                         1370.0                    7
# 4       58.146                         2336.0                    6
#
#    restaurant_rating  delivery_charges  restaurant_node  customer_node
# 0                NaN            4.3510       1327098193     3260985583
# 1                NaN            5.1515        871096404      777826283
# 2                NaN            6.5655       1327098193     2288769482
# 3                NaN               NaN        871096404     6167289287
# 4                NaN               NaN       6167191696      650269226

# %%
missing["shortest_distance_to_customer"].isnull().sum()
# Out:
# 0

# %% [markdown]
# We can now see that there are no more missing values in the `shortest_distance_to_customer` column.
#
# We will drop the `restaurant_node` and `customer_node` columns since we don't need them anymore

# %%
missing.drop(columns = ["restaurant_node", "customer_node"], inplace = True)
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                         1370.0                    7
# 4       58.146                         2336.0                    6
#
#    restaurant_rating  delivery_charges
# 0                NaN            4.3510
# 1                NaN            5.1515
# 2                NaN            6.5655
# 3                NaN               NaN
# 4                NaN               NaN

# %% [markdown]
# ### 4.3 restaurant_rating
#
# Since we established the values of `restaurant_id` in `missing` are the same as those in `dirty`, the `restaurant_rating` for each restaurant will be the same. We will create a series `dirty_ratings` that groups each `restaurant_id` with its `restaurant_rating` from `dirty`

# %%
dirty_ratings = dirty.groupby("restaurant_id")["restaurant_rating"].unique()
dirty_ratings
# Out:
# restaurant_id
# REST0936    [9.58]
# REST1450    [7.71]
# REST1781    [8.27]
# REST1801    [9.72]
# REST1858    [7.06]
# Name: restaurant_rating, dtype: object

# %%
# convert restaurant_rating to float
dirty_ratings = dirty_ratings.apply(lambda x: x[0])
dirty_ratings
# Out:
# restaurant_id
# REST0936    9.58
# REST1450    7.71
# REST1781    8.27
# REST1801    9.72
# REST1858    7.06
# Name: restaurant_rating, dtype: float64

# %% [markdown]
# `restaurant_rating` in `missing` will now be imputed by applying a lambda function that retrieves the `restaurant_rating` from `dirty_ratings` through indexing it using the value of `restaurant_id` from each row in `missing`

# %%
missing["restaurant_rating"] = missing.apply(lambda x: dirty_ratings[x["restaurant_id"]], axis = 1)
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                         1370.0                    7
# 4       58.146                         2336.0                    6
#
#    restaurant_rating  delivery_charges
# 0               8.27            4.3510
# 1               9.72            5.1515
# 2               8.27            6.5655
# 3               9.72               NaN
# 4               7.71               NaN

# %%
missing["restaurant_rating"].isnull().sum()
# Out:
# 0

# %%
missing.groupby("restaurant_id")["restaurant_rating"].unique()
# Out:
# restaurant_id
# REST0936    [9.58]
# REST1450    [7.71]
# REST1781    [8.27]
# REST1801    [9.72]
# REST1858    [7.06]
# Name: restaurant_rating, dtype: object

# %% [markdown]
# We can now see that there are no more missing values in the `restaurant_rating` column

# %% [markdown]
# ### 4.4 delivery_charges
#
# The `delivery_charges` for each row will be calculated using a linear model fitted using the following variables:
#
# - travel_time_minutes
# - is_peak_time
# - is_weekend
# - restaurant_rating
#
# The linear model will be trained using the `dirty` dataframe

# %%
# initialize
lm_impute = LinearRegression()

# fit the linear model by using the explanatory columns to predict the delivery_charges column
lm_impute.fit(dirty[["travel_time_minutes", "is_peak_time", "is_weekend", "restaurant_rating"]], dirty["delivery_charges"])
# Out:
# LinearRegression()

# %% [markdown]
# We will test the model by running it on the `missing` data that contains the `delivery_charges`, we will call this new dataframe `test_df` and will only contain the required columns

# %%
test_df = missing[["travel_time_minutes", "is_peak_time", "is_weekend", "restaurant_rating", "delivery_charges"]].copy()

# drop rows with empty delivery_charges
test_df.dropna(subset = ["delivery_charges"], inplace = True)
test_df.head()
# Out:
#    travel_time_minutes  is_peak_time  is_weekend  restaurant_rating  \
# 0                    7             0           1               8.27
# 1                    2             1           1               9.72
# 2                   23             1           0               8.27
# 5                    3             0           1               8.27
# 6                    1             0           0               7.06
#
#    delivery_charges
# 0            4.3510
# 1            5.1515
# 2            6.5655
# 5            3.8776
# 6            2.9567

# %%
test_df.shape
# Out:
# (350, 5)

# %% [markdown]
# We can test how well our model performs by computing the r-squared when the fitted `delivery_charges` are compared to the true `delivery_charges` in `test_df`

# %%
# set the test explanatory data
X_test = test_df.drop(columns = "delivery_charges")

# %% [markdown]
# The r-squared computed is

# %%
print('r-squared for this model = ', lm_impute.score(X_test,test_df["delivery_charges"]))
# Out:
# r-squared for this model =  0.9605498942504166

# %% [markdown]
# This is an extremely high r-squared, which indicates that our model is excellent for predicting `delivery_charges` (maybe too excellent and indicates over-fitting, but we will not investigate this further in this report).
#
# We will impute the missing `delivery_charges` in the `missing` dataframe using the model we fit

# %%
# impute missing values by running the model on the rows that contain the missing values and the explanatory columns only
missing.loc[missing["delivery_charges"].isnull(), "delivery_charges"] = lm_impute.predict(missing.loc[missing["delivery_charges"].isnull(),
                                                                                                      [column for column in test_df.columns if column != "delivery_charges"]])

# %%
missing.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD105989      REST1781   CUST11240   COUR4882    -37.799476    144.936815
# 1  ORD322559      REST1801   CUST07028   COUR4957    -37.803883    144.957440
# 2  ORD049292      REST1781   CUST09653   COUR0307    -37.801484    145.004298
# 3  ORD155078      REST1801   CUST13998   COUR0281    -37.810416    144.961486
# 4  ORD276190      REST1450   CUST05808   COUR0507    -37.814478    144.978845
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-24  14:42:11             0           1       Motorbike
# 1  2020-03-07  12:19:46             1           1             Car
# 2  2020-11-16  12:47:28             1           0            Bike
# 3  2020-12-25  02:42:11             0           0            Bike
# 4  2020-07-21  07:15:09             0           0             Car
#
#                                        shopping_cart  coupon_discount  \
# 0        [('beef burger', 3), ('chicken burger', 2)]               20
# 1  [('tandoori chicken', 2), ('chicken guntur', 3...               10
# 2  [('veggie pizza', 2), ('chicken burger', 3), (...               20
# 3  [('crispy chicken', 3), ('naan', 1), ('tandoor...               10
# 4  [('poha', 3), ('jalebi', 3), ('puri sabzi', 1)...               40
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0       40.360                         3585.0                    7
# 1       70.839                          837.0                    2
# 2       64.600                         4699.0                   23
# 3      110.853                         1370.0                    7
# 4       58.146                         2336.0                    6
#
#    restaurant_rating  delivery_charges
# 0               8.27          4.351000
# 1               9.72          5.151500
# 2               8.27          6.565500
# 3               9.72          3.243755
# 4               7.71          3.440263

# %%
missing["delivery_charges"].isnull().sum()
# Out:
# 0

# %% [markdown]
# We can now see that there are no more missing values in the `delivery_charges` column

# %%
missing.isnull().sum()
# Out:
# order_id                         0
# restaurant_id                    0
# customer_id                      0
# carrier_id                       0
# customer_lat                     0
# customer_lon                     0
# date                             0
# time                             0
# is_peak_time                     0
# is_weekend                       0
# carrier_vehicle                  0
# shopping_cart                    0
# coupon_discount                  0
# order_price                      0
# shortest_distance_to_customer    0
# travel_time_minutes              0
# restaurant_rating                0
# delivery_charges                 0
# dtype: int64

# %% [markdown]
# All the missing values have been imputed

# %%
# save updated missing csv
#missing.to_csv("missing_solution.csv", index = False)

# %% [markdown]
# ## 5. Outliers
#
# The `outliers` file will now be investigated. Outliers are restricted to the `delivery_charges` column. This section will investigate these outliers and will remove them from the data.
#
# To discover the outliers, a new column of delivery charges will be created using the linear model developed in the previous section. Then, the difference between the original `delivery_charges` and the new ones will be calculated to generate the residuals. A boxplot of the residuals will then be generated to identify the outliers and remove them.
#
# ### 5.1 Explore delivery_charges
#
# `delivery_charges` column in `outliers` will be investigated

# %%
outliers.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD193789      REST1858   CUST06387   COUR4937    -37.816387    144.945970
# 1  ORD252840      REST1858   CUST05819   COUR0177    -37.812716    144.981611
# 2  ORD029373      REST0936   CUST00507   COUR2343    -37.802308    144.930172
# 3  ORD067078      REST1858   CUST02343   COUR0756    -37.806544    145.010707
# 4  ORD233746      REST1858   CUST08375   COUR0735    -37.812600    144.953903
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-05  11:32:18             0           0             Car
# 1  2020-04-19  19:15:09             1           1             Car
# 2  2020-01-20  11:04:36             0           0             Car
# 3  2020-02-20  17:20:26             0           0       Motorbike
# 4  2020-06-13  18:19:46             1           1            Bike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('kerala parotta', 2), ('appam', 1), ('beef f...                0
# 1  [('mackerel fry', 1), ('beef fry', 3), ('appam...                0
# 2  [('begun pora', 3), ('banana chips', 1), ('ten...                0
# 3                  [('roast beef', 2), ('appam', 3)]                0
# 4  [('kerala parotta', 3), ('beef fry', 1), ('mac...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0        58.28                           4041                   10
# 1        78.21                           1183                    3
# 2       112.78                           1340                    3
# 3       102.12                           3804                    8
# 4       100.53                           3490                   17
#
#    delivery_charges
# 0            3.8921
# 1            5.6392
# 2            3.0330
# 3            3.4953
# 4            6.9749

# %%
outliers.shape
# Out:
# (500, 17)

# %% [markdown]
# The `outliers` data is missing the `restaurant_rating` column present in the previous files. This column will have to be added to this data as it is needed when calculating the new delivery charges using the linear model.
#
# Let's examine the summary statistics of `delivery_charges`

# %%
outliers["delivery_charges"].describe()
# Out:
# count    500.000000
# mean       4.136391
# std        1.154420
# min        1.331000
# 25%        3.330575
# 50%        3.924550
# 75%        4.714825
# max       10.170300
# Name: delivery_charges, dtype: float64

# %% [markdown]
# Graphical summaries of `delivery_charges` will be created

# %%
outliers["delivery_charges"].hist()
# Out:
# <AxesSubplot:>

# %%
outliers.boxplot(column='delivery_charges')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Judging by the summary statistics and graphs above, outliers seem to be present at values above 8. However, further investigation is required

# %% [markdown]
# ### 5.2 Add restaurant_rating
#
# `delivery_charges` is calculated based on four variables:
#
# - travel_time_minutes
# - is_peak_time
# - is_weekend
# - restaurant_rating
#
# Since `restaurant_rating` is missing, it will be added to the data. We will use the `dirty_ratings` from **section 4.3** to create the `restaurant_rating` column for each `restaurnat_id` in `outliers`. `dirty_ratings` will be reproduced here for reference

# %%
dirty_ratings
# Out:
# restaurant_id
# REST0936    9.58
# REST1450    7.71
# REST1781    8.27
# REST1801    9.72
# REST1858    7.06
# Name: restaurant_rating, dtype: float64

# %%
# compute missing restaurant_rating as was done in section 4.3
outliers["restaurant_rating"] = outliers.apply(lambda x: dirty_ratings[x["restaurant_id"]], axis = 1)
outliers.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD193789      REST1858   CUST06387   COUR4937    -37.816387    144.945970
# 1  ORD252840      REST1858   CUST05819   COUR0177    -37.812716    144.981611
# 2  ORD029373      REST0936   CUST00507   COUR2343    -37.802308    144.930172
# 3  ORD067078      REST1858   CUST02343   COUR0756    -37.806544    145.010707
# 4  ORD233746      REST1858   CUST08375   COUR0735    -37.812600    144.953903
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-05  11:32:18             0           0             Car
# 1  2020-04-19  19:15:09             1           1             Car
# 2  2020-01-20  11:04:36             0           0             Car
# 3  2020-02-20  17:20:26             0           0       Motorbike
# 4  2020-06-13  18:19:46             1           1            Bike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('kerala parotta', 2), ('appam', 1), ('beef f...                0
# 1  [('mackerel fry', 1), ('beef fry', 3), ('appam...                0
# 2  [('begun pora', 3), ('banana chips', 1), ('ten...                0
# 3                  [('roast beef', 2), ('appam', 3)]                0
# 4  [('kerala parotta', 3), ('beef fry', 1), ('mac...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0        58.28                           4041                   10
# 1        78.21                           1183                    3
# 2       112.78                           1340                    3
# 3       102.12                           3804                    8
# 4       100.53                           3490                   17
#
#    delivery_charges  restaurant_rating
# 0            3.8921               7.06
# 1            5.6392               7.06
# 2            3.0330               9.58
# 3            3.4953               7.06
# 4            6.9749               7.06

# %% [markdown]
# The `restaurant_rating` column has now been included in `outliers`

# %% [markdown]
# ### 5.3 Identify Outliers
#
# The column `new_charges` will be created using the linear model from **section 4.4**

# %%
# predict using explanatory columns
outliers["new_charges"] = lm_impute.predict(outliers[[column for column in test_df.columns if column != "delivery_charges"]])
outliers.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD193789      REST1858   CUST06387   COUR4937    -37.816387    144.945970
# 1  ORD252840      REST1858   CUST05819   COUR0177    -37.812716    144.981611
# 2  ORD029373      REST0936   CUST00507   COUR2343    -37.802308    144.930172
# 3  ORD067078      REST1858   CUST02343   COUR0756    -37.806544    145.010707
# 4  ORD233746      REST1858   CUST08375   COUR0735    -37.812600    144.953903
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-05  11:32:18             0           0             Car
# 1  2020-04-19  19:15:09             1           1             Car
# 2  2020-01-20  11:04:36             0           0             Car
# 3  2020-02-20  17:20:26             0           0       Motorbike
# 4  2020-06-13  18:19:46             1           1            Bike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('kerala parotta', 2), ('appam', 1), ('beef f...                0
# 1  [('mackerel fry', 1), ('beef fry', 3), ('appam...                0
# 2  [('begun pora', 3), ('banana chips', 1), ('ten...                0
# 3                  [('roast beef', 2), ('appam', 3)]                0
# 4  [('kerala parotta', 3), ('beef fry', 1), ('mac...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0        58.28                           4041                   10
# 1        78.21                           1183                    3
# 2       112.78                           1340                    3
# 3       102.12                           3804                    8
# 4       100.53                           3490                   17
#
#    delivery_charges  restaurant_rating  new_charges
# 0            3.8921               7.06     3.943342
# 1            5.6392               7.06     5.716291
# 2            3.0330               9.58     2.857867
# 3            3.4953               7.06     3.740015
# 4            6.9749               7.06     7.139584

# %% [markdown]
# We will now calculate the `residual` by calculating the difference between `delivery_charges` and `new_charges`

# %%
outliers["residual"] = outliers["delivery_charges"] - outliers["new_charges"]
outliers.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD193789      REST1858   CUST06387   COUR4937    -37.816387    144.945970
# 1  ORD252840      REST1858   CUST05819   COUR0177    -37.812716    144.981611
# 2  ORD029373      REST0936   CUST00507   COUR2343    -37.802308    144.930172
# 3  ORD067078      REST1858   CUST02343   COUR0756    -37.806544    145.010707
# 4  ORD233746      REST1858   CUST08375   COUR0735    -37.812600    144.953903
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-05  11:32:18             0           0             Car
# 1  2020-04-19  19:15:09             1           1             Car
# 2  2020-01-20  11:04:36             0           0             Car
# 3  2020-02-20  17:20:26             0           0       Motorbike
# 4  2020-06-13  18:19:46             1           1            Bike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('kerala parotta', 2), ('appam', 1), ('beef f...                0
# 1  [('mackerel fry', 1), ('beef fry', 3), ('appam...                0
# 2  [('begun pora', 3), ('banana chips', 1), ('ten...                0
# 3                  [('roast beef', 2), ('appam', 3)]                0
# 4  [('kerala parotta', 3), ('beef fry', 1), ('mac...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0        58.28                           4041                   10
# 1        78.21                           1183                    3
# 2       112.78                           1340                    3
# 3       102.12                           3804                    8
# 4       100.53                           3490                   17
#
#    delivery_charges  restaurant_rating  new_charges  residual
# 0            3.8921               7.06     3.943342 -0.051242
# 1            5.6392               7.06     5.716291 -0.077091
# 2            3.0330               9.58     2.857867  0.175133
# 3            3.4953               7.06     3.740015 -0.244715
# 4            6.9749               7.06     7.139584 -0.164684

# %% [markdown]
# Now we will create a boxplot of the residuals to locate the outliers

# %%
outliers.boxplot(column='residual')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Judging by the boxplot, any observations where the value of the `residual` is greater than 1 or less than -1 is considered an outlier.
#
# Let's extract those observations

# %%
out = outliers[abs(outliers["residual"]) > 1]
out
# Out:
#       order_id restaurant_id customer_id carrier_id  customer_lat  \
# 39   ORD239476      REST1450   CUST06467   COUR2042    -37.803233
# 50   ORD112468      REST1450   CUST13074   COUR1017    -37.822506
# 60   ORD097909      REST1801   CUST03844   COUR2938    -37.813255
# 61   ORD061493      REST1858   CUST10555   COUR4087    -37.822928
# 67   ORD023808      REST0936   CUST11893   COUR0871    -37.813016
# 76   ORD097715      REST1801   CUST05385   COUR3263    -37.809614
# 85   ORD033225      REST1858   CUST03458   COUR1200    -37.821958
# 109  ORD212654      REST1858   CUST10012   COUR1300    -37.805470
# 147  ORD167164      REST1858   CUST09586   COUR4636    -37.815037
# 150  ORD076204      REST0936   CUST03768   COUR0198    -37.820620
# 163  ORD181487      REST1781   CUST06962   COUR0700    -37.805248
# 172  ORD019108      REST0936   CUST02692   COUR1951    -37.800011
# 177  ORD288430      REST0936   CUST10094   COUR1907    -37.817682
# 210  ORD283529      REST1801   CUST08793   COUR0610    -37.799973
# 232  ORD067599      REST1801   CUST08404   COUR3799    -37.800378
# 257  ORD226220      REST0936   CUST02797   COUR3409    -37.818092
# 291  ORD232231      REST0936   CUST03268   COUR1294    -37.805567
# 293  ORD349874      REST1858   CUST01334   COUR1251    -37.799357
# 302  ORD253987      REST0936   CUST12449   COUR2574    -37.818726
# 303  ORD338715      REST0936   CUST02716   COUR1286    -37.822806
# 343  ORD216906      REST1858   CUST06882   COUR1689    -37.805416
# 363  ORD092720      REST1450   CUST03541   COUR1733    -37.815425
# 404  ORD229196      REST1450   CUST04504   COUR0667    -37.822527
# 405  ORD043221      REST1450   CUST10044   COUR1717    -37.798945
# 406  ORD147052      REST1858   CUST13791   COUR4302    -37.810383
# 413  ORD244144      REST1801   CUST00650   COUR2665    -37.809091
# 428  ORD111345      REST1781   CUST10446   COUR1982    -37.819933
# 458  ORD157713      REST1781   CUST04273   COUR0455    -37.824124
# 478  ORD092849      REST1858   CUST07391   COUR0603    -37.823527
# 483  ORD068564      REST0936   CUST05551   COUR2147    -37.813224
#
#      customer_lon        date      time  is_peak_time  is_weekend  \
# 39     144.996644  2020-02-16  00:59:20             0           1
# 50     144.969287  2020-12-07  14:58:01             0           0
# 60     144.985628  2020-06-24  07:07:15             0           0
# 61     144.937166  2020-01-26  11:36:15             0           1
# 67     144.973967  2020-08-24  20:54:03             0           0
# 76     144.971128  2020-12-10  04:40:52             0           0
# 85     144.993850  2020-03-03  08:30:19             0           0
# 109    144.997289  2020-03-14  01:54:43             0           1
# 147    145.014287  2020-08-31  21:29:40             0           0
# 150    144.948737  2020-12-06  00:23:44             0           1
# 163    144.950819  2020-11-29  06:23:44             0           1
# 172    144.968488  2020-03-02  10:32:58             0           0
# 177    144.983171  2020-07-25  10:32:58             0           1
# 210    144.962540  2020-05-27  19:03:17             1           0
# 232    144.963954  2020-04-05  21:05:56             0           1
# 257    145.004087  2020-04-26  01:11:12             0           1
# 291    144.944940  2020-12-21  09:41:32             0           0
# 293    144.972748  2020-03-11  12:43:30             1           0
# 302    144.953284  2020-12-01  11:20:26             0           0
# 303    145.009337  2020-01-02  08:14:30             0           0
# 343    144.961520  2020-01-08  06:55:23             0           0
# 363    144.991540  2020-08-29  02:10:32             0           1
# 404    144.973959  2020-04-04  03:53:24             0           1
# 405    144.986615  2020-04-27  00:07:54             0           0
# 406    144.968317  2020-08-11  21:29:40             0           0
# 413    144.946208  2020-05-04  22:13:11             0           0
# 428    144.932372  2020-09-08  01:19:07             0           0
# 458    144.986838  2020-03-30  18:15:49             1           0
# 478    144.969339  2020-07-31  04:32:58             0           0
# 483    144.948536  2020-06-18  16:13:11             0           0
#
#     carrier_vehicle                                      shopping_cart  \
# 39        Motorbike                 [('jalebi', 3), ('puri sabzi', 3)]
# 50        Motorbike    [('jalebi', 3), ('puri sabzi', 2), ('poha', 3)]
# 60        Motorbike  [('naan', 2), ('crispy chicken', 1), ('tandoor...
# 61        Motorbike                        [('appam', 1), ('fish', 1)]
# 67              Car  [('mocha chingri', 1), ('cheesecake', 1), ('be...
# 76             Bike  [('naan', 3), ('crispy chicken', 3), ('chicken...
# 85              Car                  [('roast beef', 3), ('appam', 3)]
# 109            Bike  [('beef fry', 2), ('mackerel fry', 2), ('fish'...
# 147             Car                   [('crab toast', 1), ('fish', 1)]
# 150       Motorbike             [('begun pora', 1), ('cheesecake', 1)]
# 163       Motorbike  [('mango salad', 2), ('peri peri chicken wings...
# 172             Car  [('banana chips', 2), ('saffron pilaf', 2), ('...
# 177       Motorbike        [('banana chips', 2), ('mocha chingri', 3)]
# 210            Bike  [('tandoori chicken', 1), ('naan', 2), ('panne...
# 232            Bike  [('hyderabadi biryani', 1), ('tandoori chicken...
# 257             Car             [('paratha', 2), ('saffron pilaf', 2)]
# 291             Car          [('mocha chingri', 2), ('begun pora', 3)]
# 293       Motorbike                  [('appam', 2), ('crab toast', 3)]
# 302       Motorbike  [('mocha chingri', 2), ('saffron pilaf', 1), (...
# 303            Bike  [('begun pora', 3), ('banana chips', 3), ('saf...
# 343             Car         [('roast beef', 3), ('kerala parotta', 2)]
# 363       Motorbike  [('samosa', 3), ('poha', 1), ('rasgulla', 2), ...
# 404             Car                      [('kachori', 2), ('poha', 2)]
# 405       Motorbike                 [('puri sabzi', 2), ('jalebi', 3)]
# 406       Motorbike  [('appam', 2), ('roast beef', 3), ('mackerel f...
# 413       Motorbike  [('hyderabadi biryani', 3), ('panner tikka', 2...
# 428             Car           [('mango salad', 1), ('beef burger', 3)]
# 458            Bike  [('chicken burger', 3), ('beef burger', 3), ('...
# 478            Bike   [('fish', 2), ('mackerel fry', 2), ('appam', 2)]
# 483       Motorbike              [('banana chips', 3), ('paratha', 3)]
#
#      coupon_discount  order_price  shortest_distance_to_customer  \
# 39                 0       89.400                           4836
# 50                 0       94.690                           1814
# 60                20       79.144                           3345
# 61                 0       36.810                           4673
# 67                45       36.278                           4358
# 76                45       47.498                           1951
# 85                 0      123.360                            972
# 109                0       79.960                           2670
# 147               20       18.064                           3630
# 150               40       22.278                           2510
# 163               10       90.459                           2031
# 172                0      124.260                           4016
# 177               20       77.128                           5492
# 210               20       48.184                            264
# 232                0       45.490                            378
# 257                0       66.240                           7263
# 291                0      112.220                           1265
# 293                0       56.710                           3134
# 302                0      139.900                           2586
# 303               20      174.640                           7942
# 343                0       91.400                           3115
# 363               40       78.042                           3537
# 404                0       33.000                           2193
# 405                0       69.670                           4247
# 406               10      104.229                           2155
# 413                0       60.850                           2019
# 428                0       49.610                           3712
# 458                0      201.690                           2718
# 478               10       88.452                           1620
# 483               40       51.948                           2223
#
#      travel_time_minutes  delivery_charges  restaurant_rating  new_charges  \
# 39                    10           7.44135               7.71     4.856664
# 50                     4           1.77015               7.71     3.236935
# 60                     7           4.81980               9.72     3.243755
# 61                     9           7.12035               7.06     4.851424
# 67                    10           1.96385               9.58     3.569514
# 76                    10           5.21880               9.72     3.548746
# 85                     2           1.72135               7.06     3.130032
# 109                   13           2.52085               7.06     5.258079
# 147                    9           1.91980               7.06     3.841678
# 150                    5           6.00390               9.58     4.070941
# 163                    4           2.01980               8.27     4.163608
# 172                   10           5.15490               9.58     3.569514
# 177                   11           6.76920               9.58     4.680924
# 210                    1           6.44235               9.72     4.108621
# 232                    2           5.51340               9.72     3.745181
# 257                   17           7.99800               9.58     5.290906
# 291                    3           1.33450               9.58     2.857867
# 293                    6           7.39035               7.06     5.011537
# 302                    5           1.69850               9.58     3.061195
# 303                   40          10.17030               9.58     6.619429
# 343                    7           1.90315               7.06     3.638351
# 363                    7           7.13730               7.71     4.551672
# 404                    5           2.21835               7.71     4.348345
# 405                    8           5.70570               7.71     3.643591
# 406                    4           1.69935               7.06     3.333359
# 413                    4           1.33100               9.72     2.938763
# 428                    9           1.88785               8.27     3.662182
# 458                   14           2.81125               8.27     5.645350
# 478                    8           5.40510               7.06     3.740015
# 483                    4           1.48735               9.58     2.959531
#
#      residual
# 39   2.584686
# 50  -1.466785
# 60   1.576045
# 61   2.268926
# 67  -1.605664
# 76   1.670054
# 85  -1.408682
# 109 -2.737229
# 147 -1.921878
# 150  1.932959
# 163 -2.143808
# 172  1.585386
# 177  2.088276
# 210  2.333729
# 232  1.768219
# 257  2.707094
# 291 -1.523367
# 293  2.378813
# 302 -1.362695
# 303  3.550871
# 343 -1.735201
# 363  2.585628
# 404 -2.129995
# 405  2.062109
# 406 -1.634009
# 413 -1.607763
# 428 -1.774332
# 458 -2.834100
# 478  1.665085
# 483 -1.472181

# %%
out.shape
# Out:
# (30, 20)

# %% [markdown]
# We have 30 outlier observations.
#
# We will now drop these observations

# %%
outliers.drop(index = out.index, inplace = True)
outliers.shape
# Out:
# (470, 20)

# %% [markdown]
# We have successfully removed the outliers.
#
# We'll remove the columns we no longer need

# %%
outliers.drop(columns = ["restaurant_rating", "new_charges", "residual"], inplace = True)
outliers.head()
# Out:
#     order_id restaurant_id customer_id carrier_id  customer_lat  customer_lon  \
# 0  ORD193789      REST1858   CUST06387   COUR4937    -37.816387    144.945970
# 1  ORD252840      REST1858   CUST05819   COUR0177    -37.812716    144.981611
# 2  ORD029373      REST0936   CUST00507   COUR2343    -37.802308    144.930172
# 3  ORD067078      REST1858   CUST02343   COUR0756    -37.806544    145.010707
# 4  ORD233746      REST1858   CUST08375   COUR0735    -37.812600    144.953903
#
#          date      time  is_peak_time  is_weekend carrier_vehicle  \
# 0  2020-05-05  11:32:18             0           0             Car
# 1  2020-04-19  19:15:09             1           1             Car
# 2  2020-01-20  11:04:36             0           0             Car
# 3  2020-02-20  17:20:26             0           0       Motorbike
# 4  2020-06-13  18:19:46             1           1            Bike
#
#                                        shopping_cart  coupon_discount  \
# 0  [('kerala parotta', 2), ('appam', 1), ('beef f...                0
# 1  [('mackerel fry', 1), ('beef fry', 3), ('appam...                0
# 2  [('begun pora', 3), ('banana chips', 1), ('ten...                0
# 3                  [('roast beef', 2), ('appam', 3)]                0
# 4  [('kerala parotta', 3), ('beef fry', 1), ('mac...                0
#
#    order_price  shortest_distance_to_customer  travel_time_minutes  \
# 0        58.28                           4041                   10
# 1        78.21                           1183                    3
# 2       112.78                           1340                    3
# 3       102.12                           3804                    8
# 4       100.53                           3490                   17
#
#    delivery_charges
# 0            3.8921
# 1            5.6392
# 2            3.0330
# 3            3.4953
# 4            6.9749

# %%
# save updated outliers csv
#outliers.to_csv("outlier_solution.csv", index = False)

# %% [markdown]
# ## 6. Conclusion
#
# This assignment displayed various methods and techniques relating to data wrangling and data cleansing. For all three tasks, the `pandas` library was the main workhorse and backbone of all the work performed.
#
# Regarding the `dirty` file, errors were discovered by either examining the columns in relation to themselves only by identifying the values were acceptable, as was the case with the `date` column, or by cross referencing the columns with other columns to verify their validity, such as with the `is_weekend` and `order_price` columns. Some errors were fixed in a straightforward fashion such as ensuring that `peak_time` were in fact inside the peak times according to the `time` column. While others required a more complicated procedure such as using the `SentimentIntensityAnalyzer` from the `nltk` library to generate the restaurant ratings or using the `Dijkstra algorithm` from the `networkx` library to compute the `shortest_distance_to_customer`.
#
# Concerning the `missing` file, methods of imputing the missing values included using prior-learned knowledge as was done when imputing `restaurant_rating`, as well as the use of linear regression to create a model that predicted the missing `delivery_charges`.
#
# Finally for the `outliers` file, the linear regression model was again used to calculated predicted values, which were then used to calculate the residual for each observation, and using a boxplot of the residuals, the outliers were successfully identified and removed.

# %% [markdown]
# ## 7. References
#
# - Aric A. Hagberg, Daniel A. Schult and Pieter J. Swart, “Exploring network structure, dynamics, and function using NetworkX”, in Proceedings of the 7th Python in Science Conference (SciPy2008), Gäel Varoquaux, Travis Vaught, and Jarrod Millman (Eds), (Pasadena, CA USA), pp. 11–15, Aug 2008
# - Bird, Steven, Edward Loper and Ewan Klein (2009), Natural Language Processing with Python. O’Reilly Media Inc.
# - Harris, C.R., Millman, K.J., van der Walt, S.J. et al. Array programming with NumPy. Nature 585, 357–362 (2020). DOI: 10.1038/s41586-020-2649-2. (Publisher link).
# - J. D. Hunter, "Matplotlib: A 2D Graphics Environment", Computing in Science & Engineering, vol. 9, no. 3, pp. 90-95, 2007.
# - McKinney, W., & others. (2010). Data structures for statistical computing in python. In Proceedings of the 9th Python in Science Conference (Vol. 445, pp. 51–56)
# - Scikit-learn: Machine Learning in Python, Pedregosa et al., JMLR 12, pp. 2825-2830, 2011.
# - Van Rossum, G. (2020). The Python Library Reference, release 3.8.2. Python Software Foundation.
